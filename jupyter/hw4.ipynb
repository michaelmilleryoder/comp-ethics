# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# from nltk import word_tokenize

from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models.keyedvectors import KeyedVectors

import os
from collections import defaultdict, Counter
from tqdm import tqdm_notebook as tqdm
import pickle
from operator import itemgetter
from IPython.core.debugger import set_trace
import numpy as np
import string

data_dirpath = '/usr2/mamille2/11-830_data/hw4'

# %% [markdown]
# # Train author ID simple classifier

# %%
# Load data
data = {}
folds = ['classtrain', 'train', 'dev', 'test']

for f in folds:
    data[f] = pd.read_csv(f'/usr2/mamille2/11-830_data/hw4/{f}.csv')
#     print(len(data[f]))

vec = CountVectorizer(min_df=2)
vec.fit(data['classtrain']['text'])

X = {}
for f in folds:
    X[f] = vec.transform(data[f]['text'])
#     print(X[f].shape)

label_dict = {'leia': 0, 'luke': 1}

y = {}
for f in folds:
    y[f] = data[f]['label'].map(lambda x: label_dict[x])
#     print(y[f].shape)

# for f in ['classtrain', 'dev', 'test']:

# Train
clf = LogisticRegression()
clf.fit(X['classtrain'], y['classtrain'])

# Get scores
for f in ['classtrain', 'dev', 'test']:
    print(f)
    preds = clf.predict(X[f])
    print(f"Accuracy: {accuracy_score(preds, y[f])}")
    print(f"Precision: {precision_score(preds, y[f])}")
    print(f"Recall: {recall_score(preds, y[f])}")
    print(f"F1: {f1_score(preds, y[f])}")
    print()
# Out:
# classtrain
# Accuracy: 0.97163
# Precision: 0.9809
# Recall: 0.9630451430478921
# F1: 0.9718905743755388
#
# dev
# Accuracy: 0.5670080142475512
# Precision: 0.5422974176313446
# Recall: 0.5704918032786885
# F1: 0.5560374343757133
#
# test
# Accuracy: 0.95695
# Precision: 0.9737
# Recall: 0.9421383647798742
# F1: 0.9576592082616179

# %% [markdown]
# # Examine data

# %%
data['train']
# Out:
#       label                                               text
# 0      luke           i ' d use this place of business again .
# 1      luke  this business was very highly rated and rightl...
# 2      luke                   great food when you can get in .
# 3      luke                    the pasta was fresh and tasty .
# 4      luke               salt & pepper calamari - delicious .
# 5      luke                          the kids devoured these .
# 6      luke             will be a staple on subsequent trips .
# 7      luke     water boiled fish - this dish was phenomenal .
# 8      luke                    starts slow & builds & builds .
# 9      luke                               great , great dish .
# 10     luke                        great way to end the meal .
# 11     luke                         super reasonable as well .
# 12     luke  super nice people , fantastic food , great val...
# 13     luke             does n't mean i ' m an expert though .
# 14     luke                                   it is one case .
# 15     luke                 these are ridiculously addictive .
# 16     luke        the food was excellent all the way around .
# 17     luke  they had a couple of soups that sounded wonder...
# 18     luke                        i ' m a fan of china lite .
# 19     luke                         i ' m a fan of <UNK> ' s .
# 20     luke  love the standard cheesesteak , typically go e...
# 21     luke           good bread , ample meat , love the wiz .
# 22     luke                              ca n't beat the wiz .
# 23     luke     the bun of the beef bun itself was fantastic .
# 24     luke                        that was a good while ago .
# 25     luke  had some work colleagues ask to meet here today .
# 26     luke           my biggest problem was the menu itself .
# 27     luke                                  it may be great .
# 28     luke   so the birthday fail begins ... one more thing .
# 29     luke                               food is a big deal .
# ...     ...                                                ...
# 99970  leia  clean , comfortable , free wi-fi , hot breakfa...
# 99971  leia  omg absolutely love this place ... the staff i...
# 99972  leia  i had previously purchased furniture from here...
# 99973  leia  worst 0 day hotel ` ` experience ' ' - lrb - <...
# 99974  leia  i would be willing to go just for the drinks ,...
# 99975  leia  i also told her to wax my upper lip - lrb - wh...
# 99976  leia  i do wish their room service - lrb - for food ...
# 99977  leia  i may have also had bk on the way back , but d...
# 99978  leia  at first , i felt badly about it , but then i ...
# 99979  leia  . i understand this is a bar but there was no ...
# 99980  leia  minus the dirty glass on the deck of the soaki...
# 99981  leia  - rrb - and the whole bottom of the burger was...
# 99982  leia  there were a few mistakes , but they were rect...
# 99983  leia  the chicken was paired with a generously sized...
# 99984  leia  i had the miyagi-san burger and it was to die ...
# 99985  leia  if you see one , pick up the groupon for a pit...
# 99986  leia  instead of playing any of our songs we request...
# 99987  leia  the portion sizes are huge and allow plenty of...
# 99988  leia  i decided to try pita jungle for dinner with a...
# 99989  leia  the boyfriend frequents the restaurant and his...
# 99990  leia  here ' s why i got 0 cupcakes one strawberry a...
# 99991  leia  cleanliness : seemed okay on the surface but t...
# 99992  leia  oh who can forget the 0 $ rose wine by the gla...
# 99993  leia  if this was applebee ' s it would be fine ... ...
# 99994  leia  when they serve it they have a bit of cotton c...
# 99995  leia  they ' re open 0 days a week , but they close ...
# 99996  leia  this dumb b * * * kept jumping up and down beh...
# 99997  leia  they say free drink for girls but provide a sh...
# 99998  leia  apparently she needs to go to customer service...
# 99999  leia  nothing out of the ordinary ... location - it ...
#
# [100000 rows x 2 columns]

# %%
# Label distribution
len(data['train'][data['train']['label']=='leia'])/len(data['train'])
# Out:
# 0.5

# %%
# Label distribution
len(data['test'][data['test']['label']=='leia'])/len(data['test'])
# Out:
# 0.5

# %%
lexica['luke']
# Out:
# ['wife',
#  '.',
#  'good',
#  'is',
#  'girlfriend',
#  'a',
#  'of',
#  'you',
#  'place',
#  'great',
#  'excellent',
#  'the',
#  'beer',
#  'as',
#  'quality',
#  'value',
#  'burger',
#  'average',
#  'in',
#  'some',
#  'its',
#  'las',
#  'this',
#  'best',
#  'solid',
#  'food',
#  'price',
#  'beers',
#  'selection',
#  'better',
#  'real',
#  'guys',
#  'from',
#  'business',
#  'buddy',
#  'strip',
#  'well',
#  'bbq',
#  'vegas',
#  'casino',
#  "''",
#  'outstanding',
#  'has',
#  'star',
#  'service',
#  'steak',
#  'these',
#  'phoenix',
#  'joint',
#  'style',
#  'sports',
#  '``',
#  'valley',
#  'notch',
#  'simply',
#  'decent',
#  'places',
#  'expect',
#  'or',
#  'gf',
#  'seems',
#  'if',
#  'bachelor',
#  'game',
#  'bad',
#  'your',
#  'high',
#  'ribs',
#  'http://url',
#  'chinese',
#  'wifey',
#  'review',
#  'pizza',
#  'than',
#  'prices',
#  'fair',
#  '`',
#  'folks',
#  'bar',
#  'bucks',
#  'brisket',
#  "'ll",
#  'most',
#  'burgers',
#  'city',
#  'chain',
#  'certainly',
#  'steaks',
#  'buffet',
#  'mexican',
#  'craft',
#  'years',
#  'ipa',
#  'standard',
#  'charlotte',
#  'cool',
#  'at',
#  'rating',
#  'town',
#  ';',
#  'italian',
#  ',',
#  'above',
#  'beef',
#  'restaurants',
#  'guy',
#  'tap',
#  'pub',
#  'range',
#  "'s",
#  'local',
#  'desert',
#  'york',
#  'cuisine',
#  'premium',
#  'chicago',
#  'tv',
#  'five',
#  'wings',
#  'south',
#  'staff',
#  'very',
#  'steakhouse',
#  'joints',
#  'vehicle',
#  'any',
#  'buddies',
#  'rib',
#  'restaurant',
#  'north',
#  'establishment',
#  'an',
#  'by',
#  'management',
#  'below',
#  'diane',
#  "'",
#  'rate',
#  'burrito',
#  'might',
#  'stars',
#  'meat',
#  'american',
#  'cheap',
#  'damn',
#  'prime',
#  'be',
#  'somewhat',
#  'avoid',
#  'should',
#  'internet',
#  'fare',
#  'couple',
#  'draft',
#  'east',
#  'sub',
#  'setup',
#  'are',
#  'ribeye',
#  'may',
#  'miles',
#  'road',
#  'west',
#  'hell',
#  'par',
#  'higher',
#  'montreal',
#  'dollar',
#  'plenty',
#  'world',
#  'level',
#  'games',
#  'four',
#  'summary',
#  'barbecue',
#  'poor',
#  'top',
#  'country',
#  'reasonable',
#  'poker',
#  'cooked',
#  'dining',
#  'repair',
#  'tough',
#  'airport',
#  'what',
#  'barber',
#  'brews',
#  'prepared',
#  'number',
#  'yourself',
#  'cost',
#  'grill',
#  'on',
#  'system',
#  'same',
#  'building',
#  'bike',
#  'pint',
#  'typical',
#  'probably',
#  'speed',
#  'old',
#  'dollars',
#  'golf',
#  'near',
#  'downtown',
#  'expensive',
#  'seem',
#  'problem',
#  'ok',
#  'cars',
#  'similar',
#  'generally',
#  'other',
#  'experience',
#  'rare',
#  'pork',
#  'brewery',
#  'pastrami',
#  'simple',
#  'indian',
#  'shit',
#  'pittsburgh',
#  'rear',
#  'parts',
#  'brew',
#  'america',
#  'likely',
#  'starbuck',
#  'operation',
#  'franchise',
#  'ny',
#  'authentic',
#  'crew',
#  'atmosphere',
#  'area',
#  'offerings',
#  'classic',
#  'taps',
#  'quantity',
#  'nearly',
#  'run',
#  'dealer',
#  'example',
#  '5',
#  'install',
#  'dude',
#  'adequate',
#  'street',
#  'built',
#  'main',
#  'far',
#  'times',
#  'dishes',
#  'diner',
#  'meats',
#  'stadium',
#  'property',
#  'grade',
#  'based',
#  'highest',
#  'relatively',
#  'product',
#  'irish',
#  'wifes',
#  'worst',
#  'fairly',
#  'among',
#  'worse',
#  'vehicles',
#  'properties',
#  'steakhouses',
#  'gay',
#  'tires',
#  'short',
#  'car',
#  'deserts',
#  'terrific',
#  'quite',
#  'result',
#  '\\',
#  'spot',
#  'gun',
#  'low',
#  'hd',
#  'everybody',
#  'upscale',
#  'favor',
#  'fine',
#  'compared',
#  'common',
#  'perhaps',
#  'preparation',
#  'fuck',
#  'three',
#  'gaming',
#  'minor',
#  'league',
#  'few',
#  'denny',
#  'traditional',
#  'truck',
#  'lower',
#  'appears',
#  'others',
#  'baseball',
#  'casinos',
#  'gk',
#  'arizona',
#  'does',
#  'pricing',
#  'unique',
#  'tremendous',
#  'football',
#  'eaten',
#  'lousy',
#  'shop',
#  'attractive',
#  'sporting',
#  'money',
#  'opinion',
#  'bone-in',
#  'new',
#  'rental',
#  'execution',
#  'gets',
#  'visits',
#  'final',
#  'blackjack',
#  'fast',
#  'crap',
#  'japanese',
#  'consider',
#  'issue',
#  'competition',
#  'ownership',
#  'more',
#  'corporate',
#  'sportsbook',
#  'costs',
#  'earned',
#  'aged',
#  'texas',
#  'thats',
#  'rated',
#  'scottsdale',
#  'united',
#  'overall',
#  'serves',
#  'garbage',
#  'finest',
#  'nfl',
#  'veal',
#  'designed',
#  'shirt',
#  'dealers',
#  'dive',
#  'generic',
#  'usa',
#  'that',
#  'in-n-out',
#  'courteous',
#  'cox',
#  'stuff',
#  'bottom',
#  'establishments',
#  'hundred',
#  'model',
#  'mike',
#  'visit',
#  'many',
#  'features',
#  'slaw',
#  'sir',
#  'mile',
#  'easily',
#  'subway',
#  'bmw',
#  'competitive',
#  'cheesesteak',
#  'hertz',
#  'effort',
#  'tint',
#  'dump',
#  'across',
#  'job',
#  'superior',
#  'ale',
#  'hundreds',
#  'hit',
#  'interior',
#  'stout',
#  'auto',
#  'hooters',
#  'cigar',
#  'seemingly',
#  'chains',
#  'interesting',
#  'ta',
#  'shirts',
#  'six',
#  'looking',
#  'joke',
#  'tourist',
#  'limited',
#  'panda',
#  'guns',
#  'original',
#  'ass',
#  'doubt',
#  'firearms',
#  'less',
#  'shot',
#  'burritos',
#  'hamburger',
#  'anybody',
#  'claim',
#  'equipment',
#  'hole',
#  'killer',
#  'period',
#  'arguably',
#  'craps',
#  'exceptional',
#  'coke',
#  'suspect',
#  'comics',
#  'advertised',
#  'peaks',
#  'tvs',
#  'proper',
#  'team',
#  'along',
#  'adjacent',
#  'cheers',
#  'mcdonald',
#  'wash',
#  'now',
#  'gordon',
#  'medium',
#  'ai',
#  '%',
#  'fortunately',
#  'bars',
#  'televisions',
#  '90',
#  'video',
#  'culinary',
#  'owner',
#  'strongly',
#  'power',
#  'scale',
#  'dudes',
#  'philly',
#  'basic',
#  'ingredients',
#  'traffic',
#  'enjoyable',
#  'greater',
#  'installed',
#  'terms',
#  'normal',
#  '?',
#  'national',
#  'ammo',
#  'passable',
#  'goto',
#  'scotch',
#  'locations',
#  'sausage',
#  'bs',
#  'location',
#  'chili',
#  'alternative',
#  'circus',
#  '4',
#  'knock',
#  'central',
#  '4.5',
#  'motor',
#  'basketball',
#  'reason',
#  'theme',
#  'several',
#  'king',
#  'negative',
#  'major',
#  'tire',
#  'located',
#  'properly',
#  'q',
#  'bone',
#  'cities',
#  'michelin',
#  'bud',
#  'arena',
#  'design',
#  'point',
#  'modest',
#  'deli',
#  'gyro',
#  'asada',
#  'carne',
#  'imo',
#  'true',
#  'layout',
#  'approach',
#  'sides',
#  'anywhere',
#  'shooting',
#  'replacement',
#  'center',
#  'wall',
#  'replaced',
#  'barbers',
#  'yeah',
#  'station',
#  'warranty',
#  'mexico',
#  'reputation',
#  'web',
#  'nothing',
#  'perspective',
#  'due',
#  'pickup',
#  'related',
#  'meal',
#  'double',
#  'provided',
#  'hilton',
#  'commercial',
#  'nice',
#  'shops',
#  'unlike',
#  'essentially',
#  'lets',
#  'neighborhood',
#  'none',
#  'find',
#  'engine',
#  'wing',
#  'crowd',
#  'ratings',
#  'pubs',
#  'golden',
#  'kilt',
#  'pro',
#  'cuts',
#  'ramsay',
#  'presented',
#  'subs',
#  'parking',
#  'tier',
#  'caesars',
#  'provides',
#  'terminal',
#  'rock',
#  'nobody',
#  'acceptable',
#  'become',
#  'large',
#  'fish',
#  'former',
#  'unreal',
#  'harbor',
#  'problems',
#  'pinball',
#  'provide',
#  'el',
#  'cooking',
#  'marginal',
#  'breweries',
#  'dont',
#  'standards',
#  'brewing',
#  'fired',
#  'greatest',
#  'fucking',
#  'buffets',
#  'buck',
#  'guinness',
#  '***',
#  'being',
#  'eatery',
#  'smoke',
#  'metro',
#  'players',
#  'priced',
#  'micro',
#  'stands',
#  'gambling',
#  'bikes',
#  'appointed',
#  'means',
#  'maintained',
#  'gourmet',
#  'supermarket',
#  'primanti',
#  'urinal',
#  'comic',
#  'fuel',
#  'ales',
#  'somebody',
#  'relative',
#  'inspection',
#  'general',
#  'depot',
#  'mark',
#  'feels',
#  'virtually',
#  'bun',
#  'wifi',
#  'type',
#  'wheels',
#  'dozens',
#  'initial',
#  'block',
#  'mgm',
#  'f',
#  'tee',
#  'cigars',
#  'cook',
#  'dinning',
#  'item',
#  'cable',
#  'institution',
#  'respectable',
#  'sport',
#  '**',
#  'rickie',
#  'char',
#  'chef',
#  'cut',
#  'margin',
#  'grand',
#  'profit',
#  'pbr',
#  'seen',
#  'trap',
#  'dave',
#  'vape',
#  'lcd',
#  'competent',
#  'tempe',
#  'reviews',
#  'dozen',
#  'news',
#  'beat',
#  'cooks',
#  'im',
#  'pints',
#  'imho',
#  'shows',
#  'track',
#  'unit',
#  'wood',
#  'regional',
#  'ranks',
#  'yards',
#  'park',
#  'elsewhere',
#  'u.s.',
#  'houses',
#  'jim',
#  'high-end',
#  'various',
#  'focus',
#  'kuge',
#  'decade',
#  'rail',
#  'resort',
#  'pound',
#  'grub',
#  'setting',
#  'un',
#  'ces',
#  'combined',
#  'watch',
#  'san',
#  'consistent',
#  'jd',
#  'mr',
#  'airline',
#  'leak',
#  'lamb',
#  'under',
#  'detail',
#  'upper',
#  'southeast',
#  'character',
#  'hotels',
#  'can',
#  'southern',
#  'improve',
#  'values',
#  'weak',
#  'popular',
#  'appearance',
#  'speeds',
#  'failure',
#  'done',
#  'dice',
#  'avenue',
#  'incredible',
#  'action',
#  'subtle',
#  'resorts',
#  'odds',
#  'twenty',
#  'largely',
#  'including',
#  'eastern',
#  'marketing',
#  'bargain',
#  'rack',
#  'ferrari',
#  'definition',
#  'ground',
#  'executed',
#  'oven',
#  'sense',
#  'competitors',
#  'wide',
#  'race',
#  'trip',
#  'cant',
#  'carolina',
#  'smashburger',
#  'series',
#  'companies',
#  'category',
#  'rates',
#  'machines',
#  'francisco',
#  'gear',
#  'primarily',
#  'roast',
#  'contrast',
#  'fillet',
#  'pizzeria',
#  'uninspiring',
#  'state',
#  'issues',
#  'german',
#  'fame',
#  'sound',
#  'recomend',
#  'recommendation',
#  'draw',
#  'overpriced',
#  'steve',
#  'runs',
#  'choice',
#  'against',
#  'motorcycle',
#  'missus',
#  'down',
#  'pace',
#  'domestic',
#  'noda',
#  'all-in-all',
#  'scratches',
#  'screw',
#  'da',
#  'clientele',
#  'express',
#  'alignment',
#  'available',
#  'urinals',
#  'numerous',
#  'spots',
#  'gas',
#  'legendary',
#  'ufc',
#  'fat',
#  'nearby',
#  'joe',
#  '$',
#  'culture',
#  'lv',
#  'uninspired',
#  'bit',
#  'tax',
#  'soccer',
#  'quick',
#  'compete',
#  'factor',
#  'nation',
#  'considerably',
#  'positive',
#  'cole',
#  'medium-rare',
#  'parkway',
#  'poorly',
#  'match',
#  'collection',
#  '10/10',
#  'sits',
#  'premier',
#  'owners',
#  'shame',
#  'palms',
#  'ought',
#  'big',
#  'jersey',
#  'previous',
#  'flagship',
#  'drawback',
#  'remarkably',
#  'honda',
#  'field',
#  'bro',
#  'massive',
#  'a.',
#  'japan',
#  'kobe',
#  'seven',
#  'cask',
#  'destination',
#  'keep',
#  'locals',
#  'volume',
#  'pedestrian',
#  'further',
#  'avis',
#  'impression',
#  'phx',
#  'inferior',
#  'damned',
#  'standpoint',
#  'into',
#  'ounce',
#  'ballpark',
#  'bianco',
#  'inn',
#  'taco',
#  'honest',
#  'trail',
#  'travel',
#  'midwood',
#  'peg',
#  'selling',
#  'rick',
#  'sell',
#  '_',
#  'record',
#  'biggest',
#  'asian',
#  'fairways',
#  'john',
#  'madison',
#  'dealership',
#  'per',
#  'del',
#  'five-star',
#  'fiancee',
#  'offering',
#  'eateries',
#  'steelers',
#  'kitchen',
#  'roughly',
#  'rank',
#  'college',
#  'sauces',
#  'diverse',
#  'china',
#  'dodge',
#  'reality',
#  'coast',
#  'oem',
#  'microbrews',
#  'wetlands',
#  'ruth',
#  'proposition',
#  '5-star',
#  'frankly',
#  'effect',
#  'clt',
#  'breakfast',
#  'inventory',
#  'duke',
#  'rivals',
#  'manhattan',
#  'marriott',
#  'taste',
#  'border',
#  'nevada',
#  'stop',
#  'decades',
#  'unless',
#  'operating',
#  'epic',
#  'link',
#  'chandler',
#  'gripe',
#  'lone',
#  'focused',
#  'scam',
#  'least',
#  'bait',
#  'unremarkable',
#  'shines',
#  'positives',
#  'consistently',
#  'devoid',
#  'flat',
#  'regard',
#  'hill',
#  'connection',
#  'mrs.',
#  'mountain',
#  'akin',
#  'suburban',
#  'coin',
#  'rather',
#  'porsche',
#  'produced',
#  'surface',
#  'fatburger',
#  'attempt',
#  'cheaper',
#  'rio',
#  'noticeably',
#  'head',
#  'pride',
#  'uptown',
#  '200',
#  'markup',
#  'tasting',
#  'county',
#  'beaten',
#  'sandwich',
#  '80',
#  'lowes',
#  'automotive',
#  'vic',
#  'jack',
#  'thousands',
#  'cheesesteaks',
#  'noticeable',
#  'famous',
#  'looks',
#  '50',
#  'knowledge',
#  'albeit',
#  'expense',
#  'where',
#  'one',
#  'airports',
#  'garage',
#  'sort',
#  'gimmick',
#  'ability',
#  'une',
#  'eight',
#  'highway',
#  'build',
#  'rise',
#  'site',
#  'wheel',
#  'distant',
#  'mastro',
#  'racing',
#  'access',
#  's',
#  '*************************',
#  'brake',
#  'sahara',
#  'kfc',
#  'ample',
#  '1',
#  'wow',
#  "'re",
#  'electric',
#  'typically',
#  'palace',
#  'term',
#  'moderate',
#  'draught',
#  'roof',
#  'transmission',
#  'latter',
#  'rewarded',
#  'feature',
#  'over',
#  'past',
#  'courses',
#  'quebec',
#  'western',
#  'railroad',
#  'becomes',
#  'substance',
#  'hand',
#  'spirits',
#  'reasonably',
#  'lesser',
#  'compressor',
#  'amazon',
#  'comparison',
#  ...]

# %%
lexica['leia']
# Out:
# ['!',
#  'husband',
#  'we',
#  'boyfriend',
#  'so',
#  'i',
#  'love',
#  'our',
#  'my',
#  'yummy',
#  'was',
#  '!!',
#  'hubby',
#  'delicious',
#  ':-rrb-',
#  'she',
#  'loved',
#  'bf',
#  'us',
#  'he',
#  'cute',
#  'were',
#  'super',
#  '&',
#  'because',
#  'ordered',
#  "n't",
#  'did',
#  'definitely',
#  'friend',
#  'chocolate',
#  'amazing',
#  'lovely',
#  'salad',
#  '!!!',
#  'her',
#  'delish',
#  'sweet',
#  'fabulous',
#  'it',
#  'got',
#  'beautiful',
#  'cake',
#  'yum',
#  '-',
#  'had',
#  'mom',
#  'hair',
#  'came',
#  'birthday',
#  'happy',
#  'excited',
#  'and',
#  'favorite',
#  'dessert',
#  'wonderful',
#  'tea',
#  'cream',
#  'wanted',
#  'really',
#  '?!',
#  'girl',
#  'sister',
#  'also',
#  'salon',
#  'wedding',
#  ':-lrb-',
#  'since',
#  'girls',
#  'too',
#  'massage',
#  'am',
#  'adorable',
#  'gorgeous',
#  'sooo',
#  'husbands',
#  'server',
#  'hubs',
#  'cupcakes',
#  'die',
#  'him',
#  'strawberry',
#  ';-rrb-',
#  'omg',
#  'cupcake',
#  'bachelorette',
#  'totally',
#  '-lrb-',
#  'could',
#  'veggie',
#  'huge',
#  'spa',
#  'okay',
#  '!!!!',
#  'rude',
#  'lol',
#  'his',
#  'which',
#  'asked',
#  'soooo',
#  '*',
#  'fun',
#  'perfect',
#  'brunch',
#  'fiance',
#  'gross',
#  'when',
#  'cheese',
#  'thank',
#  'ladies',
#  'shared',
#  'boba',
#  'veggies',
#  'vegan',
#  'even',
#  'seriously',
#  'decided',
#  'liked',
#  'gluten',
#  'everyone',
#  'absolutely',
#  'wait',
#  'vegetarian',
#  'heels',
#  'went',
#  'comfy',
#  '-rrb-',
#  'girlfriends',
#  'craving',
#  'dr.',
#  'ended',
#  'wish',
#  'lemon',
#  'back',
#  'me',
#  '=-rrb-',
#  'milk',
#  "'m",
#  'oh',
#  'such',
#  'daughter',
#  'coconut',
#  'classes',
#  'strawberries',
#  'purse',
#  'waited',
#  'told',
#  'fruit',
#  'share',
#  'nails',
#  'cookies',
#  'woman',
#  'enjoyed',
#  'latte',
#  'velvet',
#  'able',
#  'children',
#  'they',
#  'their',
#  'yoga',
#  'said',
#  'creamy',
#  'tried',
#  'groupon',
#  'soo',
#  'fave',
#  '??',
#  'everything',
#  'frosting',
#  '--',
#  'boyfriends',
#  'glad',
#  'crepe',
#  'always',
#  'divine',
#  'chose',
#  'avocado',
#  'chai',
#  'obsessed',
#  'patio',
#  'never',
#  'dressing',
#  'friends',
#  'spinach',
#  'order',
#  'vanilla',
#  'sangria',
#  'tofu',
#  'patient',
#  'disappointed',
#  'makeup',
#  'adore',
#  'son',
#  'felt',
#  'raspberry',
#  'goodness',
#  'thought',
#  'tiny',
#  '...',
#  'champagne',
#  'caramel',
#  'mini',
#  'martini',
#  'mango',
#  'macarons',
#  'hour',
#  'babies',
#  'sad',
#  'desserts',
#  'leftovers',
#  'day',
#  'bc',
#  'salmon',
#  'margarita',
#  'bathroom',
#  'starving',
#  'b/c',
#  'stylist',
#  'think',
#  'almond',
#  'nervous',
#  'drinks',
#  'gave',
#  'cookie',
#  'come',
#  'yay',
#  'free',
#  'soup',
#  'appointment',
#  'sooooo',
#  'who',
#  'fav',
#  'nutella',
#  'heaven',
#  'annoyed',
#  'brought',
#  'vet',
#  'baby',
#  'ice',
#  'bruschetta',
#  'bread',
#  'sugar',
#  'refreshing',
#  'waitress',
#  'night',
#  'dress',
#  'facial',
#  'helpful',
#  'took',
#  'mimosas',
#  'pineapple',
#  'fiancã©',
#  'color',
#  'toddler',
#  'dresses',
#  'tart',
#  'loves',
#  'forever',
#  'pedicure',
#  'dad',
#  'warm',
#  'picky',
#  'cheesecake',
#  'tummy',
#  'peach',
#  'fab',
#  'beautifully',
#  'made',
#  'roll',
#  'dinner',
#  'hummus',
#  'creme',
#  'smoothie',
#  'pesto',
#  'gal',
#  'seated',
#  'weird',
#  'office',
#  'pregnant',
#  'time',
#  'thrilled',
#  'cinnamon',
#  'cucumber',
#  'split',
#  'whole',
#  'mouth',
#  'nail',
#  'needed',
#  'called',
#  'banana',
#  'pet',
#  'salty',
#  'fresh',
#  'to-go',
#  'room',
#  'accommodating',
#  'try',
#  'bites',
#  'kale',
#  'ugh',
#  'pup',
#  'bridal',
#  'butter',
#  'already',
#  'hh',
#  'appreciated',
#  'looked',
#  'kept',
#  'brulee',
#  'cozy',
#  'incredibly',
#  'finally',
#  'dance',
#  'again',
#  'brie',
#  'dh',
#  'sat',
#  'pick',
#  'crepes',
#  'cakes',
#  'shoes',
#  'dip',
#  'haha',
#  'promoter',
#  'jewelry',
#  'mimosa',
#  'parents',
#  'bath',
#  'checked',
#  'to',
#  'bananas',
#  'fluffy',
#  'tomatoes',
#  'goat',
#  'yogurt',
#  'teeny',
#  'pear',
#  'kiddos',
#  'shrimp',
#  'bff',
#  'chairs',
#  'um',
#  'honey',
#  'grateful',
#  'brownie',
#  'allergies',
#  'iced',
#  'bed',
#  'heavenly',
#  'manicure',
#  'until',
#  'bakery',
#  'soy',
#  'date',
#  'literally',
#  'choose',
#  'macaron',
#  'luckily',
#  'flowers',
#  'green',
#  'groomer',
#  'sprouts',
#  'crazy',
#  'bday',
#  'table',
#  'rolls',
#  'kids',
#  'scared',
#  'bloody',
#  'massages',
#  'no1dp',
#  'artichoke',
#  'scrumptious',
#  'tasted',
#  'romantic',
#  'therapist',
#  'crave',
#  'lavender',
#  'treatments',
#  'animals',
#  'walked',
#  'upset',
#  'treats',
#  'garlic',
#  'fell',
#  'sharing',
#  ':d',
#  'wontons',
#  'cutest',
#  'gelato',
#  'party',
#  'kind',
#  'toast',
#  'purses',
#  'pistachio',
#  'before',
#  'ca',
#  'teas',
#  'mojito',
#  'white',
#  'pancakes',
#  'knew',
#  'ourselves',
#  'peanut',
#  'sprinkles',
#  'grooming',
#  'bummed',
#  'studio',
#  'gluten-free',
#  'squash',
#  'cm',
#  'mary',
#  'gifts',
#  'vodka',
#  '!!!!!',
#  'tuna',
#  'spicy',
#  'tub',
#  'crispy',
#  'welcoming',
#  'tickets',
#  'pumpkin',
#  'someone',
#  ':--rrb-',
#  'beds',
#  'impressed',
#  'clothes',
#  'wished',
#  'pain',
#  'pleased',
#  'hostess',
#  'thankful',
#  'towels',
#  'gift',
#  'weekend',
#  'grandma',
#  'lychee',
#  'cat',
#  'flavors',
#  'drink',
#  'nurse',
#  'gotten',
#  'salads',
#  'reservations',
#  'caprese',
#  'water',
#  'cranberry',
#  'fruity',
#  'mmmm',
#  'truffle',
#  'def',
#  'bathrooms',
#  'allergic',
#  'mousse',
#  'cocktails',
#  'pedi',
#  'helped',
#  'tooth',
#  'candy',
#  'bummer',
#  'mother',
#  'dancing',
#  'zucchini',
#  'pudding',
#  'photos',
#  'ginger',
#  'whipped',
#  'quinoa',
#  'cousin',
#  'puppy',
#  'left',
#  'blueberry',
#  'disgusting',
#  'mmm',
#  'basil',
#  'salons',
#  'fella',
#  'eh',
#  'gosh',
#  'gentle',
#  'sit',
#  'smoothies',
#  'there',
#  'bean',
#  'appt',
#  'go',
#  'flavorful',
#  'taro',
#  'bags',
#  'pool',
#  'relaxing',
#  'how',
#  'wine',
#  'pillows',
#  'pups',
#  'smelled',
#  'aveda',
#  'feta',
#  'doctor',
#  'snacks',
#  'completely',
#  'macaroons',
#  'pregnancy',
#  'tattoo',
#  'pilates',
#  'pastries',
#  'juice',
#  'irritated',
#  'ate',
#  'idk',
#  'watermelon',
#  'favorites',
#  'beets',
#  'complimentary',
#  'edamame',
#  'wee',
#  'basket',
#  'received',
#  'croissant',
#  'mochi',
#  'w',
#  'ravioli',
#  'ceremony',
#  'margaritas',
#  'pink',
#  'ready',
#  'honestly',
#  'lattes',
#  'bellini',
#  'sigh',
#  'exhibit',
#  'samples',
#  'options',
#  'raved',
#  'healthy',
#  'esp',
#  'deliciousness',
#  'tons',
#  'sweetest',
#  'home',
#  'uncomfortable',
#  'melty',
#  'lil',
#  'awhile',
#  'delightful',
#  'questions',
#  'shower',
#  'pomegranate',
#  'yuck',
#  '=d',
#  'tempura',
#  'homemade',
#  'granola',
#  'teacher',
#  'cheesy',
#  'costumes',
#  '=-lrb-',
#  'ppl',
#  'grossed',
#  'cocktail',
#  'garlicky',
#  'candles',
#  'ricotta',
#  'married',
#  'eggplant',
#  'vinaigrette',
#  'gel',
#  'berry',
#  'instead',
#  'flatbread',
#  'yesterday',
#  'fondue',
#  'niece',
#  'waters',
#  'sick',
#  'eyebrows',
#  'glasses',
#  'fruits',
#  'child',
#  'suggested',
#  'check',
#  'extensions',
#  'treatment',
#  'soooooo',
#  'dentist',
#  'waffle',
#  'berries',
#  'freezing',
#  'yucky',
#  'cucumbers',
#  'awkward',
#  'holiday',
#  'melt',
#  'hubbie',
#  'robes',
#  'blankets',
#  'booked',
#  'mommy',
#  'sisters',
#  'exam',
#  'rushed',
#  'facials',
#  'faves',
#  'asparagus',
#  'pictures',
#  'awful',
#  'lemonade',
#  'offered',
#  'skin',
#  'event',
#  'dr',
#  'mac',
#  'appointments',
#  'hospital',
#  'fur',
#  'scones',
#  'panini',
#  'body',
#  'brussel',
#  'drizzled',
#  'decadent',
#  'butternut',
#  'sundae',
#  'salted',
#  'mil',
#  'vanity',
#  'christmas',
#  'danced',
#  'hazelnut',
#  'buttery',
#  'chic',
#  'bestie',
#  'unprofessional',
#  'waxing',
#  'bangs',
#  'dream',
#  'tomato',
#  'allergy',
#  'would',
#  'potatoes',
#  'wrap',
#  'creepy',
#  'pasta',
#  'tiramisu',
#  'coz',
#  'piercing',
#  'britney',
#  'listened',
#  'adored',
#  'know',
#  'waiter',
#  'coupons',
#  'teeth',
#  'comforter',
#  'splurge',
#  'picked',
#  'quiche',
#  'returning',
#  '?!?!',
#  'sorbet',
#  'lover',
#  'pets',
#  'til',
#  'appreciate',
#  'groomed',
#  'cups',
#  'scrub',
#  'dying',
#  'yumminess',
#  'appetizer',
#  'saw',
#  'mint',
#  'beet',
#  'downfall',
#  'moved',
#  'calories',
#  'women',
#  '|',
#  'organic',
#  'prosecco',
#  'licked',
#  'organized',
#  'mani',
#  'mushroom',
#  'guac',
#  'blanket',
#  'charming',
#  'for',
#  'bfs',
#  'dietary',
#  'seaweed',
#  'sparkly',
#  'ew',
#  'cried',
#  'dye',
#  'stuffed',
#  'ginormous',
#  'addicted',
#  ':-d',
#  'oreo',
#  'acai',
#  'r.',
#  'goodies',
#  'toddlers',
#  'lotion',
#  'needless',
#  'realized',
#  'surgery',
#  'worried',
#  'servers',
#  'photographer',
#  'rudely',
#  'zumba',
#  'go-to',
#  ':p',
#  'reception',
#  'emergency',
#  "s'mores",
#  'celebrate',
#  'mani/pedi',
#  'doctors',
#  'bring',
#  'plus',
#  'blonde',
#  'horrible',
#  'thorough',
#  'kindly',
#  'teachers',
#  'crunchy',
#  'balsamic',
#  'chair',
#  'pieces',
#  'loooove',
#  'topped',
#  'cuz',
#  'hate',
#  'cauliflower',
#  'risotto',
#  'yummiest',
#  'marshmallow',
#  'kiddo',
#  'buttercream',
#  'cats',
#  'rehearsal',
#  'booth',
#  'aunt',
#  'savory',
#  'practically',
#  'dipping',
#  'listens',
#  'brownies',
#  'crab',
#  'dirty',
#  'chocolates',
#  'coupon',
#  'guestlist',
#  'receptionist',
#  'matcha',
#  'almonds',
#  'tanning',
#  'photo',
#  'remembered',
#  'each',
#  'olives',
#  'yummm',
#  'daycare',
#  'lime',
#  'answered',
#  'shortcake',
#  'apple',
#  'colors',
#  'spas',
#  'tears',
#  'chocolatey',
#  'feel',
#  'instructors',
#  'cravings',
#  'beloved',
#  'dreaming',
#  'pedicures',
#  'rice',
#  'fro-yo',
#  'pics',
#  'pad',
#  'hunnie',
#  'stairs',
#  'groom',
#  'face',
#  'toiletries',
#  'raving',
#  'girly',
#  'chandeliers',
#  'celebration',
#  'arugula',
#  'bride',
#  'bunnie',
#  'fig',
#  'scallop',
#  'pita',
#  'tarts',
#  'mangoes',
#  'stalls',
#  'books',
#  'scary',
#  'lettuce',
#  'indecisive',
#  'burrata',
#  'lady',
#  'purchased',
#  'groomers',
#  'benedict',
#  'brussels',
#  'boo',
#  'cider',
#  'grapefruit',
#  'duper',
#  'robe',
#  ':]',
#  'sitting',
#  'hunt',
#  'accommodate',
#  'chip',
#  'meh',
#  'dog',
#  'ages',
#  'cherry',
#  'forgot',
#  'busy',
#  'bedroom',
#  'clothing',
#  'colada',
#  'swear',
#  'martinis',
#  'greet',
#  'melted',
#  'barely',
#  'pleasantly',
#  'group',
#  'ummm',
#  'loving',
#  'accidentally',
#  'housekeeping',
#  '-_-',
#  'wear',
#  'sis',
#  'wanting',
#  '=]',
#  'teavana',
#  'qua',
#  'hesitant',
#  'sephora',
#  'although',
#  'bras',
#  'lemony',
#  'patients',
#  'handbags',
#  'ours',
#  'pgh',
#  'valentine',
#  'sip',
#  'h&m',
#  'attentive',
#  'icky',
#  'fabric',
#  'devoured',
#  'shampoo',
#  'cannoli',
#  'twins',
#  'petsmart',
#  'stylists',
#  'overwhelming',
#  'broccoli',
#  'bathtub',
#  'just',
#  'rave',
#  'beyond',
#  'bundt',
#  'reservation',
#  'stressful',
#  'bite',
#  'chilly',
#  'prescriptions',
#  'kittens',
#  'walnuts',
#  'orange',
#  'looooove',
#  'hubster',
#  'pina',
#  'intimate',
#  'peaceful',
#  'but',
#  'scone',
#  'resist',
#  'thrift',
#  'souvenir',
#  'mussels',
#  'drizzle',
#  'phone',
#  'chatted',
#  'person',
#  'theirs',
#  'yummmm',
#  'bubbly',
#  'anxiety',
#  'decorated',
#  'brã»lã©e',
#  'misters',
#  'apples',
#  'kindness',
#  'hangry',
#  'spacious',
#  'ah-mazing',
#  'certificate',
#  'nurses',
#  'friendly',
#  'sweets',
#  'vintage',
#  'sang',
#  'stroller',
#  'drooling',
#  'wayyy',
#  'baths',
#  'mushrooms',
#  'both',
#  'layers',
#  'urgent',
#  'mocha',
#  'macaroon',
#  'syrup',
#  'sparkling',
#  'freaked',
#  'tour',
#  'cashier',
#  'pierced',
#  'birthdays',
#  'doggie',
#  'different',
#  'postino',
#  'manicures',
#  'scallops',
#  'ask',
#  'sweetheart',
#  'medications',
#  'deliciously',
#  'condensed',
#  'masseuse',
#  'extremely',
#  'happily',
#  'marshmallows',
#  'hairdresser',
#  'calm',
#  'earrings',
#  'puffs',
#  '???',
#  'have',
#  'appalled',
#  'homey',
#  'filling',
#  'pancake',
#  'together',
#  'bouquet',
#  'eater',
#  'wth',
#  'saturday',
#  'horrified',
#  'maternity',
#  'jelly',
#  'yes',
#  'glass',
#  'medication',
#  'icing',
#  'suggestions',
#  'hilarious',
#  'morning',
#  'plantain',
#  'muffin',
#  'rescue',
#  'started',
#  'potato',
#  'riesling',
#  'exhausted',
#  'leggings',
#  'sticky',
#  'ridiculous',
#  'jacuzzi',
#  'planner',
#  'red',
#  'casino-by-casino',
#  'chewy',
#  'gooey',
#  'guava',
#  'mine',
#  'turkey',
#  'cleanse',
#  'fridge',
#  'shopping',
#  'guests',
#  'flower',
#  'apartment',
#  'seeds',
#  ...]

# %% [markdown]
# # Add to Leia and Luke lexica

# %%
# Build probability tables
assoc = {'leia': {}, 'luke': {}}
texts = {}
texts['leia'] = [w for d in data['train'][data['train']['label']=='leia']['text'].tolist() for w in d.split() if not w in stops]
texts['luke'] = [w for d in data['train'][data['train']['label']=='luke']['text'].tolist() for w in d.split() if not w in stops]
train_vocab = set(texts['leia']).union(set(texts['luke']))
counters = {'leia': Counter(texts['leia']), 'luke': Counter(texts['luke'])}
total_counter = counters['leia'] + counters['luke']
doc_count = {name: len(data['train'][data['train']['label']==name]) for name in authors}

for name in authors:
    for w in tqdm(train_vocab):
        assoc[name][w] = np.log((counters[name][w]/doc_count[name]) / (total_counter[w]/len(data['train'])))
# Out:
# HBox(children=(IntProgress(value=0, max=17348), HTML(value='')))
# /usr0/home/mamille2/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log
#   del sys.path[0]
# HBox(children=(IntProgress(value=0, max=17348), HTML(value='')))

# %%
# Sorted associations
sorted_assoc = {name: sorted(assoc[name].items(), key=itemgetter(1), reverse=True) for name in authors}

# %%
# Take top n and add to lexica
top = 10000

for name in authors:
    print(name)
    for i in range(top):
        wd, assoc = sorted_assoc[name][i]
        if not wd in lexica[name]:
            lexica[name].append(wd)
            
    print(len(lexica[name]))
# Out:
# leia
# 10804
# luke
# 10617

# %%
# Save new lexica
for name in authors:
    with open(os.path.join(data_dirpath, f'{name}_{top}.txt'), 'w') as f:
        for w in lexica[name]:
            f.write(w+'\n')

# %% [markdown]
# # Identify, replace author-specific terms

# %%
lexica = {}
stops = ['a', 'the', 'of'] + [c for c in string.punctuation]
for name in ['leia', 'luke']:
    with open(os.path.join(data_dirpath, f'{name}.txt')) as f:
        lexica[name] = [w for w in f.read().splitlines() if not w in stops]
    print(len(lexica[name]))
# Out:
# 3000
# 2997

# %%
glove_model = KeyedVectors.load_word2vec_format("/usr2/mamille2/11-830_data/hw4/gensim_glove_6Bvectors300d.txt", binary=False)

len(glove_model.vocab)
# Out:
# 400000

# %% [markdown]
# ## Build mapping from leia > luke lexicon

# %%
conversions = {}

# %%
# Load extended conversion list
conv_path = os.path.join(data_dirpath, 'lexicon_sims_10000.pkl')
print('Loading conversion lists...')
with open(conv_path, 'rb') as f:
    conversions['extended'] = pickle.load(f)
print(len(conversion['luke']))
print(len(conversion['leia']))
# Out:
# Loading conversion lists...
# 10166
# 10187

# %%
# Load original conversion list
conv_path = os.path.join(data_dirpath, 'lexicon_sims_3000.pkl')
with open(conv_path, 'rb') as f:
    conversions['orig'] = pickle.load(f)
print(len(conversion['leia']))
print(len(conversion['luke']))
# Out:
# 2917
# 2679

# %%
for name in authors:
    print(len(special_conversion[name]))
# Out:
# 10187
# 10166

# %%
conversions['extended'] = special_conversion

# %%
conversion = {}
conversion['leia'] = {} # Target is Leia's speech
conversion['luke'] = {}

authors = ['leia', 'luke']
for name in authors:
    print(name)
    other = [a for a in authors if a!=name][0]
    
    for w in tqdm(lexica[other]):
        if w in glove_model.vocab:
            conversion[name][w] = sorted([(glove_model.similarity(w, other_w), rank, other_w) for rank, other_w in enumerate(lexica[name]) if other_w in glove_model.vocab], reverse=True)

# Save similarities
# conv_path = os.path.join(data_dirpath, 'lexicon_sims_luke_extended_leia_orig.pkl')
# with open(conv_path, 'wb') as f:
#     pickle.dump(conversion, f)
# Out:
# leia
# HBox(children=(IntProgress(value=0, max=2997), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-df7d0877ef2a> in <module>()
#      10     for w in tqdm(lexica[other]):
#      11         if w in glove_model.vocab:
# ---> 12             conversion[name][w] = sorted([(glove_model.similarity(w, other_w), rank, other_w) for rank, other_w in enumerate(lexica[name]) if other_w in glove_model.vocab], reverse=True)
#      13
#      14 # Save similarities
#
# <ipython-input-14-df7d0877ef2a> in <listcomp>(.0)
#      10     for w in tqdm(lexica[other]):
#      11         if w in glove_model.vocab:
# ---> 12             conversion[name][w] = sorted([(glove_model.similarity(w, other_w), rank, other_w) for rank, other_w in enumerate(lexica[name]) if other_w in glove_model.vocab], reverse=True)
#      13
#      14 # Save similarities
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py in similarity(self, w1, w2)
#     826
#     827         """
# --> 828         return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#     829
#     830     def n_similarity(self, ws1, ws2):
#
# KeyboardInterrupt:

# %%
conversion['leia']['wife']
# Out:
# [(0.86463905943091457, 1, 'husband'),
#  (0.84308741832967493, 140, 'daughter'),
#  (0.80870149281341941, 460, 'mother'),
#  (0.7343635981724328, 563, 'married'),
#  (0.70373893088560702, 1086, 'daughters'),
#  (0.69169295249234264, 62, 'sister'),
#  (0.68089037680147291, 8099, 'father'),
#  (0.67667515116835109, 7550, 'grandmother'),
#  (0.67516156845518138, 35, 'her'),
#  (0.6694897401467258, 572, 'niece'),
#  (0.66527166451062381, 192, 'son'),
#  (0.65429199982189712, 29, 'friend'),
#  (0.62811667698436624, 1460, 'granddaughter'),
#  (0.62243296618177568, 468, 'cousin'),
#  (0.61271282713328368, 9267, 'couple'),
#  (0.60902210852241245, 745, 'aunt'),
#  (0.60336544379573442, 15, 'she'),
#  (0.60022967604749222, 1630, 'brother'),
#  (0.59869925990638828, 151, 'woman'),
#  (0.58550354983788977, 4716, 'whom'),
#  (0.57655378387779466, 807, 'lady'),
#  (0.57410036263328246, 3, 'boyfriend'),
#  (0.5518234406347734, 9099, 'marry'),
#  (0.54136929771820019, 326, 'parents'),
#  (0.54084921718376222, 1117, 'herself'),
#  (0.37400168959583724, 27, 'did'),
#  (0.37381202506543909, 2581, 'jealous'),
#  (0.37271476148697996, 8177, 'while'),
#  (0.37264434771508909, 9185, 'visited'),
#  (0.37253646087548625, 146, 'told'),
#  (0.37232892399924694, 1386, 'telling'),
#  (0.37223454039151188, 8811, 'ago'),
#  (0.37096432760845283, 248, 'took'),
#  (0.37086269041058062, 9834, 'asks'),
#  (0.37011691206777342, 9723, 'young'),
#  (0.36932274062124859, 1613, 'leave'),
#  (0.3686597988680122, 8533, 'months'),
#  (0.36851723444071122, 9165, 'own'),
#  (0.36849447354374898, 256, 'loves'),
#  (0.36809667507664867, 1082, 'christine'),
#  (0.36800134230282305, 2843, 'remembers'),
#  (0.36779787192664914, 162, 'tried'),
#  (0.36766765158019216, 7231, 'theresa'),
#  (0.36764516513401058, 8278, 'became'),
#  (0.36737375580993903, 5892, 'henry'),
#  (0.36646446206221772, 777, 'beloved'),
#  (0.36548500194835204, 124, 'went'),
#  (0.36529676278136203, 2079, 'boy'),
#  (0.36477229237005293, 3422, 'worker'),
#  (0.36400310028627714, 6999, 'elderly'),
#  (0.36329406934456626, 6550, 'elaine'),
#  (0.36212995391973446, 1008, 'only'),
#  (0.36186048033262969, 2842, 'jennifer'),
#  (0.36160816665696088, 6316, 'julie'),
#  (0.36134142605888753, 828, 'bedroom'),
#  (0.36118160353647738, 7633, 'hannah'),
#  (0.36118080532273955, 129, 'dr.'),
#  (0.36115895209404342, 9848, 'actually'),
#  (0.3596358117181056, 8071, 'leaving'),
#  (0.35949241035824447, 63, 'also'),
#  (0.3593936560123942, 10769, 'partner'),
#  (0.35826886233520627, 470, 'left'),
#  (0.35808691043775509, 8167, 'cousins'),
#  (0.35798997010500949, 4, 'so'),
#  (0.35792501115264164, 4646, 'longtime'),
#  (0.35690339791045833, 9683, 'believed'),
#  (0.35668005622828691, 890, 'but'),
#  (0.35617413707816303, 8468, 'afterward'),
#  (0.35578845628588046, 8754, 'charles'),
#  (0.35570861976092211, 8194, 'fact'),
#  (0.35506035435441963, 1737, 'heather'),
#  (0.35474548987734028, 8510, 'estate'),
#  (0.35459162719586068, 10049, 'age'),
#  (0.3540400232391413, 2044, 'christina'),
#  (0.35377605250528932, 2653, 'spoke'),
#  (0.35372304581202874, 50, 'happy'),
#  (0.35219854045324062, 9239, 'companions'),
#  (0.35190839722153539, 196, 'thought'),
#  (0.35176091684213162, 4792, 'actor'),
#  (0.35156196208160689, 235, 'brought'),
#  (0.35100222583276458, 10679, 'slept'),
#  (0.35079955273624758, 10786, 'two'),
#  (0.35063678351092714, 1026, 'stayed'),
#  (0.35034946360887775, 9791, 'where'),
#  (0.3502722097466987, 9378, 'working'),
#  (0.34941377817330571, 649, 'know'),
#  (0.34909485831632908, 4122, 'karen'),
#  (0.34905235350581248, 1584, 'ellen'),
#  (0.34894628935751693, 9377, 'name'),
#  (0.34870082211221032, 9713, 'with'),
#  (0.34831983773997749, 222, 'gave'),
#  (0.34771486930099982, 8293, 'talked'),
#  (0.34743416334853933, 5828, 'kelly'),
#  (0.3474118052916052, 947, 'happily'),
#  (0.34722699914738581, 4921, 'sally'),
#  (0.3462181088266485, 3396, 'denise'),
#  (0.34594320950078233, 279, 'time'),
#  (0.34594033470668317, 9786, 'older'),
#  (0.34593440187256036, 10215, 'mansion'),
#  (0.34565869661104315, 8903, 'days'),
#  (0.34557876782478619, 1095, 'explained'),
#  (0.3453293475011146, 3321, 'president'),
#  (0.3452584063058714, 1918, 'arrived'),
#  (0.34518930672379111, 1674, 'farmer'),
#  (0.34518252695876384, 674, 'moved'),
#  (0.34510362937903921, 10491, 'allen'),
#  (0.34507097865198499, 10340, 'resident'),
#  (0.34506218440902875, 3969, 'cynthia'),
#  (0.34468351003955566, 7995, 'convinced'),
#  (0.3441570790619069, 267, 'made'),
#  (0.3436224825681472, 923, 'both'),
#  (0.34349080637798191, 9317, 'wants'),
#  (0.34337104824825099, 24, 'because'),
#  (0.34329433168559648, 160, 'said'),
#  (0.34306048683424706, 173, 'always'),
#  (0.34295183979359295, 6384, 'leslie'),
#  (0.34151055287891846, 6328, 'claire'),
#  (0.34146037285230918, 40, 'got'),
#  (0.34100520308008581, 133, 'back'),
#  (0.34069865813655137, 613, 'hospital'),
#  (0.3404391853780534, 1152, 'waiting'),
#  (0.34032100842338775, 3460, 'spencer'),
#  (0.34001270497359648, 9506, 'sue'),
#  (0.33966192261921507, 7982, 'afterwards'),
#  (0.33942887034496455, 8411, 'if'),
#  (0.33876813583734205, 3710, 'finds'),
#  (0.3383936173329638, 710, 'photographer'),
#  (0.33761044875416735, 9687, 'persuaded'),
#  (0.33718099966122456, 941, 'sweetheart'),
#  (0.33691860314527766, 5333, 'secretly'),
#  (0.33680287035311662, 7922, 'prostitute'),
#  (0.33647021508900027, 4435, 'buried'),
#  (0.33603141719743496, 5960, 'teenager'),
#  (0.33556812610008441, 119, 'everyone'),
#  (0.33546131135984025, 10220, 'traveled'),
#  (0.33518324121808951, 8822, 'earl'),
#  (0.33513260893693581, 4368, 'cindy'),
#  (0.3342431801967099, 10002, 'personally'),
#  (0.3340018259970528, 5007, 'lynn'),
#  (0.33386650648061533, 3551, 'jenny'),
#  (0.3338133548199711, 114, 'even'),
#  (0.33340666892500476, 5624, 'gloria'),
#  (0.33303098718309493, 1563, 'them'),
#  (0.33284915355328426, 959, 'together'),
#  (0.33275185068281282, 6223, 'recalled'),
#  (0.33265867414622158, 3454, 'tipper'),
#  (0.33265676673662503, 1366, 'guilty'),
#  (0.33254121827615185, 313, 'again'),
#  (0.33246425770479088, 9574, 'behalf'),
#  (0.33243224457204279, 137, "'m"),
#  (0.33207080120039179, 873, 'just'),
#  (0.33176725957115472, 10742, 'same'),
#  (0.33127261547810882, 8855, 'neighbor'),
#  (0.33072960801303286, 8613, 'refused'),
#  (0.33060678391463677, 157, 'they'),
#  (0.33025666793196767, 7312, 'roommate'),
#  (0.32990952761182624, 307, 'kept'),
#  (0.32974279542615692, 4485, 'jail'),
#  (0.3296205098836027, 2046, 'weeks'),
#  (0.31213880695691576, 9222, 'that'),
#  (0.31211692107409167, 210, 'day'),
#  (0.3116764443990343, 347, 'bed'),
#  (0.31128009540890283, 7769, 'officer'),
#  (0.31127841082851698, 9350, 'get'),
#  (0.31127442007740719, 9371, 'out'),
#  (0.31113431109883383, 4174, 'sharon'),
#  (0.3110199607900247, 8409, 'saying'),
#  (0.31096141170409913, 8014, 'female'),
#  (0.31087540074069653, 8110, 'meanwhile'),
#  (0.31081240951096295, 2387, 'insisted'),
#  (0.3106052204913447, 7502, 'williams'),
#  (0.31056404213817979, 2946, 'still'),
#  (0.31030190497110532, 9775, 'honor'),
#  (0.30890078413412697, 8074, 'whether'),
#  (0.30863655592005773, 3313, 'carla'),
#  (0.30855846535919634, 8834, 'staying'),
#  (0.30837672020709583, 1195, 'paid'),
#  (0.30828055619981976, 667, 'dying'),
#  (0.30793850833004066, 6538, 'nicholas'),
#  (0.30774036459073589, 10100, 'initially'),
#  (0.30749500106685662, 3820, 'ethel'),
#  (0.30740390634417319, 3252, 'musician'),
#  (0.30707906425331138, 693, 'cried'),
#  (0.30666758011789669, 9019, 'tracy'),
#  (0.30655178110201697, 9853, 'about'),
#  (0.30653115219988569, 7521, 'presumably'),
#  (0.30649103872725902, 8598, 'remember'),
#  (0.30597030038223827, 158, 'their'),
#  (0.30577971692760092, 6986, 'davis'),
#  (0.30573292819213227, 9279, 'attended'),
#  (0.30571168368720447, 277, 'office'),
#  (0.30509431263810433, 8676, 'teenage'),
#  (0.30505567415095153, 9381, 'visiting'),
#  (0.30446983787590354, 8591, 'mind'),
#  (0.30430485670821633, 8474, 'denied'),
#  (0.30417382735642606, 8812, 'find'),
#  (0.30411341925442292, 491, 'how'),
#  (0.30397337847442307, 6264, 'joyce'),
#  (0.3037777968169002, 10800, 'cared'),
#  (0.3037379407082817, 3291, 'arranged'),
#  (0.303187893035825, 1628, 'request'),
#  (0.30309841380956787, 5344, 'harris'),
#  (0.30303094649096024, 8799, 'talking'),
#  (0.30297651411711068, 996, 'guests'),
#  (0.30285812635353682, 4889, 'banker'),
#  (0.30283037500827586, 9240, 'katie'),
#  (0.30244020647227382, 5726, 'leah'),
#  (0.30242174610345102, 9502, 'sleeping'),
#  (0.30233029341820289, 10701, 'you'),
#  (0.30182793730605123, 6030, 'albert'),
#  (0.30162546370453325, 5645, 'joanna'),
#  (0.30153859989632581, 6953, 'witness'),
#  (0.30132776239101811, 3600, 'illness'),
#  (0.30120866875860014, 9188, 'during'),
#  (0.30105195459007589, 7627, 'victoria'),
#  (0.30061092372263543, 427, 'wished'),
#  (0.30031104599138952, 2127, 'judy'),
#  (0.3000210127464687, 657, 'returning'),
#  (0.29950075578520113, 6700, 'filed'),
#  (0.29947157221436566, 4993, 'jenna'),
#  (0.29947035010588008, 4545, 'molly'),
#  (0.2994028841776819, 1052, 'however'),
#  (0.29903048575815538, 8299, 'seeing'),
#  (0.29885470079626458, 8931, 'charged'),
#  (0.29861695613526684, 2059, 'trying'),
#  (0.29817800032719588, 7990, 'invited'),
#  (0.22959868777871725, 626, 'christmas'),
#  (0.22956026965664753, 6724, 'abusive'),
#  (0.22955362537616858, 7954, 'chloe'),
#  (0.22946890831503486, 2955, 'mention'),
#  (0.22939904218726415, 5403, 'mona'),
#  (0.22930352516179164, 4330, 'attends'),
#  (0.22919494024807868, 8212, 'closest'),
#  (0.22912410827139384, 9253, 'film'),
#  (0.22910171413865407, 963, 'saturday'),
#  (0.22906288030083252, 8513, 'settled'),
#  (0.22896702009564601, 6934, 'consultant'),
#  (0.22881447031780042, 6002, 'lawrence'),
#  (0.22880621778295024, 7276, 'carrying'),
#  (0.22878004548085942, 502, 'pregnancy'),
#  (0.2287467311946503, 7270, 'cohen'),
#  (0.22867098412663278, 1037, 'planning'),
#  (0.22857988016481018, 808, 'purchased'),
#  (0.22855151964942566, 8725, 'account'),
#  (0.22805426645547464, 1925, 'friday'),
#  (0.22801741446269475, 10093, 's'),
#  (0.22798881219977074, 9976, 'hard'),
#  (0.22793823391427137, 8871, 'concerned'),
#  (0.22792157974666014, 10777, 'many'),
#  (0.22790243351484868, 9866, 'began'),
#  (0.22786220768778204, 9337, 'caught'),
#  (0.22782273332035055, 8294, 'longer'),
#  (0.22772978839194558, 827, 'busy'),
#  (0.22767948648752201, 9906, 'official'),
#  (0.22729097655449398, 10546, 'london'),
#  (0.22717963072177788, 2058, 'zoe'),
#  (0.22714310527422021, 10740, 'managed'),
#  (0.2271233188865168, 744, 'booth'),
#  (0.22703565725780531, 8098, 'whenever'),
#  (0.22688509231298284, 9187, 'early'),
#  (0.22680822175658416, 3547, 'legally'),
#  (0.22674107398315119, 10739, 'inside'),
#  (0.22671206352541029, 171, 'glad'),
#  (0.22666296552613396, 8382, 'supervisor'),
#  ...]

# %% [markdown]
# ## Obfuscate

# %%
def obfuscate(text, tgt, threshold, conversion, mod):
    
    toks = text.split()
    obf_toks = []
    
    for t in toks:
        if t in conversion[tgt] and conversion[tgt][t][0][0] > threshold:
#             obf_toks.append(conversion[name][t][0][-1])
            candidates = []
            for i in range(len(conversion[tgt][t])):
                item = conversion[tgt][t][i]
                if item[0] > threshold and not item[-1] in stops:
                    candidates.append(item)
                else:
                    break
                    
            # Select highest ranked among candidates
#             ranked = sorted(conversion[name][t], key=itemgetter(1))
#             for i in range(len(ranked)):
#                 if ranked[i][0] > threshold:
#                     obf_toks.append(ranked[i][-1])
#                     break
                    
            best = sorted(candidates, key=itemgetter(1))[0]
            if mod == 'mod':
                if best[-1] == t:
                    obf_toks.append(best[-1])
                else:
                    obf_toks.append(best[-1]+'z')
            else:
                obf_toks.append(best[-1])
            
        else:
#             if mod == 'mod':
#                 obf_toks.append(t+'z')
#             else:
#                 obf_toks.append(t)
            obf_toks.append(t)
            
    return ' '.join(obf_toks)

# %%
# folds = ['train', 'dev', 'test']
# folds = ['train', 'test']
folds = ['test']
authors = ['leia', 'luke']
# thresholds = [0.3, 0.5, 0.7]
thresholds = [0.5, 0.7]
# thresholds = [0.3]
lexicon = 'extended'
# lexicon = 'orig'
label_dict = {'leia': 0, 'luke': 1}
reverse_label_dict = {0: 'leia', 1: 'luke'}
# mod = 'mod'
mod = 'mod'

for t in thresholds:
    print(t)
    
    X = {}
    y = {}
    
    for f in folds:
        for name in authors:
            data[f][f'obfuscated_{lexicon}_{t}_{name}_{mod}'] = \
                    list(map(lambda x: obfuscate(x, name, t, conversions[lexicon], mod), tqdm(data[f]['text'].tolist())))

        for name in authors:
            print(f"Target: {name}")
            X[f] = vec.transform(data[f][f'obfuscated_{lexicon}_{t}_{name}_{mod}'])
            y[f] = data[f]['label'].map(lambda x: label_dict[x])

            # Get scores
            preds = clf.predict(X[f])
            data[f][f'obfuscated_{lexicon}_{t}_{name}_{mod}_preds'] = [reverse_label_dict[p] for p in preds]
            print(f"Accuracy: {accuracy_score(preds, y[f])}")
    #         print(f"Precision: {precision_score(preds, y[f])}")
    #         print(f"Recall: {recall_score(preds, y[f])}")
    #         print(f"F1: {f1_score(preds, y[f])}")
            print()
        print()
    print()
# Out:
# 0.5
# HBox(children=(IntProgress(value=0, max=20000), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20000), HTML(value='')))
# Target: leia
# Accuracy: 0.59965
#
# Target: luke
# Accuracy: 0.5597
#
#
#
# 0.7
# HBox(children=(IntProgress(value=0, max=20000), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20000), HTML(value='')))
# Target: leia
# Accuracy: 0.6196
#
# Target: luke
# Accuracy: 0.59205

# %%
data['test'].columns
# Out:
# Index(['label', 'text', 'obfuscated_leia', 'obfuscated_luke',
#        'obfuscated_extended_0.3_leia', 'obfuscated_extended_0.3_luke',
#        'obfuscated_orig_0.3_leia', 'obfuscated_orig_0.3_luke',
#        'obfuscated_extended_0.3_leia_mod', 'obfuscated_extended_0.3_luke_mod',
#        'obfuscated_extended_0.3_leia_mod_preds',
#        'obfuscated_extended_0.3_luke_mod_preds',
#        'obfuscated_extended_0.5_leia_mod', 'obfuscated_extended_0.5_luke_mod',
#        'obfuscated_extended_0.5_leia_mod_preds',
#        'obfuscated_extended_0.5_luke_mod_preds',
#        'obfuscated_extended_0.7_leia_mod', 'obfuscated_extended_0.7_luke_mod',
#        'obfuscated_extended_0.7_leia_mod_preds',
#        'obfuscated_extended_0.7_luke_mod_preds',
#        'obfuscated_extended_0.5_leia_nomod',
#        'obfuscated_extended_0.5_luke_nomod',
#        'obfuscated_extended_0.5_leia_nomod_preds',
#        'obfuscated_extended_0.5_luke_nomod_preds',
#        'obfuscated_extended_0.7_leia_nomod',
#        'obfuscated_extended_0.7_luke_nomod',
#        'obfuscated_extended_0.7_leia_nomod_preds',
#        'obfuscated_extended_0.7_luke_nomod_preds'],
#       dtype='object')

# %% [markdown]
# ## Error analysis

# %%
pd.set_option('display.max_colwidth', -1)

# %%
data['test'].loc[:, ['text','obfuscated_extended_0.5_leia_mod', 'obfuscated_extended_0.5_luke_mod',
                    'label', 'obfuscated_extended_0.5_leia_mod_preds', 'obfuscated_extended_0.5_luke_mod_preds']]
# Out:
#                                                                                                                                                                                                                                           text  \
# 0      ok but not special .
# 1      my wife ordered the tenderloin sliders .
# 2      not the best i ever had but good .
# 3      while not traditional , both are tasty .
# 4      all excellent and perfectly cooked .
# 5      they are the most flavorful of the animal .
# 6      and the bonus , no corkage .
# 7      the food was extremely edible .
# 8      the chicken and broccoli is also very good .
# 9      i ordered yellowtail and they gave me red snapper .
# 10     that alone is a priceless gift .
# 11     the vermicelli noodles are good too .
# 12     the bad egg is a joke .
# 13     nephew got the ribs .
# 14     pretty much the opposite of fall off the bone .
# 15     the pasta pomodoro and chicken marsala were excellent .
# 16     highly recommended to everyone !
# 17     six cars deep waiting for valet , no thanks .
# 18     now on to trying to get a seat .
# 19     well , yeah , and more beer .
# 20     the taps were a disappointment .
# 21     a timer was set for 00 minutes .
# 22     the server did finally show up .
# 23     having deliveries does n't count .
# 24     the locker room is clean .
# 25     $ 0.00 pints of rogue ?
# 26     it ' s not the typical bar scene sounds .
# 27     yes , i said it .
# 28     i could swim in their gin and tonics .
# 29     but hey , that ' s me .
# ...                        ...
# 19970  the space is interesting so visit this place just to see the <UNK> like the old elevator shaft , the mirrored hallway to the bathroom , and the hidden dj booth !
# 19971  my neighbor was robbed in the parking lot at 0 in the morning .
# 19972  we got to sample favors before deciding which one to get .
# 19973  i figured there would be some changes to their menu as well .
# 19974  i was happy with the basil / tomato / chicken panini ... stuffed .
# 19975  that being said ... i would n't make the shrimp with candied walnuts and honeydew melon at home and i admit it is great tasting !
# 19976  room cards : we were four people with four cards but only one worked , and when we asked for new ones they gave us replacements that did n't work either ... .
# 19977  i ' m usually not a fan of sauce but the flavours were bursting .
# 19978  it ended up with great minds think alike and angela had ordered the exact same as me so the girl brought out a big pot of tea .
# 19979  this was one of the best meals i ' ve had in madison hands down .
# 19980  they made us an elvis ` ` record ' ' cake with lemon cake and mixed up the cupcakes with lemon , chocolate and vanilla with an adorable sugar shamrock on top .
# 19981  we went in earlier than the rest of the group and wound up sitting with the group from toronto by mistake due to <UNK> on our parts ; our group had a different reservation two hours after we arrived and we were not informed of it .
# 19982  denny ' s does a better job than you and they ' re not even high end !
# 19983  not to worry though , a new server came and for the rest of the evening he was great at getting us our drinks .
# 19984  go for the patio , the bottomless mimosas and a nice day drinking experience .
# 19985  when i got the the restaurant i was a little disappointed to find that the salads were pre-made .
# 19986  we had tickets for the front stage area , standing room only .
# 19987  the roasted chicken , turkey lasagna or spaghetti squash casserole are perfect if you ' re looking for some comfort food .
# 19988  the mushrooms tasted really weird for some reason and the sauce was too tangy .
# 19989  one of their young retail guy josh , literally helped my mom and i for over 0 hours ! ! he was so helpful from the smallest question about an application to picking out a new upgraded phone .
# 19990  you can have green tea hot or iced , or you can have soda or beer or plum wine !
# 19991  considering my meal was $ 00 for the fish alone , this was a great offer .
# 19992  how can i be craving a rocket burger reuben and i have only had 0 in my life ?
# 19993  i do n't know how they do it but they put just the right amount of everything in these sandwiches .
# 19994  there are also times when the line to get any food is so long that one has to do without .
# 19995  the menu was pretty big and i ' d like to try a lot of different things they have .
# 19996  overall we were really happy with the food and excellent customer service .
# 19997  all of this will be worth it - i promise .
# 19998  anyone know how much grease a green pepper would put out ?
# 19999  anyhow , we had stayed in the princess suite which included a full kitchen , living room with pull-out bed , bedroom with two queen beds , a huge bathroom w / shower & bathtub with jets , and a balcony .
#
#                                                                                                                                                                                                                         obfuscated_extended_0.5_leia_mod  \
# 0      !z wez wez special wez
# 1      husbandz husbandz orderedz the grilledz sliderz wez
# 2      wez the n'tz wez wez wez wez wez wez
# 3      soz wez folkz wez wez wez deliciousz wez
# 4      wez wonderfulz soz perfectz deliciousz wez
# 5      wez wez the soz deliciousz of the petz wez
# 6      soz the bonusz wez wez corkage wez
# 7      the drinksz soz soz fruitz wez
# 8      the saladz soz veggiesz soz soz wez wez wez
# 9      wez orderedz yellowtail soz wez gave !z greenz snapper wez
# 10     wez soz soz a priceless gift wez
# 11     the noodlesz tofuz wez wez wez wez
# 12     the soz milkz soz a funz wez
# 13     nephew wez the bruisedz wez
# 14     wez wez the opposite of becausez soz the tissuez wez
# 15     the saladz pomodoro soz saladz marsala soz wonderfulz wez
# 16     soz suggestedz wez wez !z
# 17     werez mercedesz deeperz waiting soz conciergez wez wez enjoyedz wez
# 18     wez itz wez trying wez wez a seat wez
# 19     wez wez !z wez soz wez drinksz wez
# 20     the tappedz soz a disappointedz wez
# 21     a timersz soz whichz soz 00z hourz wez
# 22     the server wez wez tonightz wez wez
# 23     having deliveries wez wez countingz wez
# 24     the roomz dressingz soz waterz wez
# 25     paidz 0.00 pints of rogue !z
# 26     wez --z sz wez the typesz barsz sawz weirdz wez
# 27     !z wez wez said wez wez
# 28     wez wez swim wasz wez vodkaz soz tonics wez
# 29     wez !z wez wez --z sz !z wez
# ...                             ...
# 19970  the launchz soz wonderfulz so dayz wez wez wez wez wez the <UNK> wez the girlz stairsz shaft wez the mirrored hallway wez the bathroom wez soz the stashz akaz booth !z
# 19971  husbandz friendz soz stolenz wasz the entrancez wez timez 2z wasz the morning wez
# 19972  we wez wez sample favoredz before deciding which wez wez wez wez
# 19973  wez figured wez wez wez wez differentz wez wez dessertz soz wez wez
# 19974  wez soz happy soz the basil /z tomato /z saladz paniniz !z bagsz wez
# 19975  wez wez said !z wez wez wez wez the coconutz soz candied walnuts soz honeydew mangoz timez home soz wez admit wez soz iz deliciousz !z
# 19976  dressingz cards ;z we soz werez wez soz werez cards wez wez wez hez wez soz when we asked soz whichz ones wez gave us replacements wez wez wez wez wez !z wez
# 19977  wez --z m soz wez a fanz of deliciousz wez the flavorsz soz bubblez wez
# 19978  wez ended wez soz iz minds think eagerz soz angelaz wez orderedz the exact wez soz !z so the girl brought wez a soz potz of tea wez
# 19979  wez soz wez of the n'tz vegetarianz wez --z ve wez wasz avenuez armsz soz wez
# 19980  wez soz us wasz impersonatorz !z !z recordedz --z --z cake soz lemon cake soz mixz wez the cupcakes soz lemon wez chocolate soz vanilla soz wasz adorable sugar shamrock itz seniorz wez
# 19981  we iz wasz earlier soz the wez of the group soz wound wez sitting soz the group camez detroitz wasz thinkz becausez wez <UNK> itz our regionsz andz our group wez a wez reservation werez waitz after we camez soz we soz wez informed of wez wez
# 19982  denny --z sz wez a wez soz soz !z soz wez --z re wez wez high wez !z
# 19983  wez wez worry wez wez a whichz server wez soz soz the wez of the hourz he soz iz timez wez us our chocolatez wez
# 19984  !z soz the patioz wez the bottomless mimosas soz a definitelyz day drinksz ourz wez
# 19985  when wez wez the the dinnerz wez soz a soz definitelyz wez wez wez the deliciousz soz pre-made wez
# 19986  we wez tickets soz the front stage outsidez wez standing dressingz wez wez
# 19987  the deliciousz saladz wez turkeyz pestoz soz pastaz squash zucchiniz wez beautifulz wez !z --z re wez soz wez comfortsz drinksz wez
# 19988  the mushrooms tastedz wez weird soz wez wez soz the deliciousz soz wez deliciousz wez
# 19989  wez of wez girlz shoppingz iz mattz wez literallyz helped husbandz mom soz wez soz soz 2z waitz !z !z he soz so helpfulz camez the smallerz wez soz wasz requestz wez picking wez a whichz upgradedz phone wez
# 19990  !z wez wez greenz tea warmz soz drinksz wez soz !z wez wez drinksz soz drinksz soz plum dessertz !z
# 19991  alreadyz husbandz deliciousz soz paidz 00z soz the salmonz soz wez wez soz a iz offer wez
# 19992  wez wez wez wez craving a launchedz burger reuben soz wez wez wez wez 2z wasz husbandz soz !z
# 19993  wez wez wez wez wez wez wez wez wez wez wez wez the wez amount of wez wasz wez deliciousz wez
# 19994  wez wez soz evenz when the runningz wez wez wez drinksz soz so soz wez wez soz wez wez wez wez
# 19995  the dessertz soz wez soz soz wez --z dz wez wez wez a wez of wez wez wez wez wez
# 19996  decreasez we soz wez happy soz the drinksz soz wonderfulz customerz service wez
# 19997  wez of wez wez wez purchasez wez - wez comez wez
# 19998  wez wez wez wez grease a greenz lemonz wez wez wez !z
# 19999  anywayz wez we wez wentz wasz the princess suitez which werez a evenz bathroomz wez living dressingz soz pull-out bed wez bedroom soz werez ladyz bedz wez a hugez bathroom w /z shower & bathtub soz planesz wez soz a patioz wez
#
#                                                                                                                                                                                                           obfuscated_extended_0.5_luke_mod  \
# 0      ok .z not special .
# 1      goodz wife judgez the steakz sliders .
# 2      not the best .z ever somez .z good .
# 3      .z not traditional .z .z are tasty .
# 4      all excellent .z seemsz cooked .
# 5      .z are the most saucesz of the meatz .
# 6      .z the bonusz .z no corkage .
# 7      the food .z wellz edible .
# 8      the steakz .z turnipsz is .z very good .
# 9      .z judgez yellowtail .z .z thatz goodz soxz grouperz .
# 10     .z alone is a valuablez donationz .
# 11     the vermicelli cookedz are good .z .
# 12     the bad eggsz is a joke .
# 13     wifez goodz the ribs .
# 14     pretty .z the opposite of fall .z the bone .
# 15     the pizzaz pomodoro .z steakz marsala .z excellent .
# 16     highly recommended .z goodz youz
# 17     six cars deep 'llz .z valet .z no thanks .
# 18     now .z .z youz .z .z a seatsz .
# 19     well .z yeah .z .z .z beer .
# 20     the taps .z a shamez .
# 21     a timerz .z fivez .z 00z 10z .
# 22     the webz .z ifz tvz .z .
# 23     .z deliveryz does .z countsz .
# 24     the locker diningz is cleanz .
# 25     $ 0.00 pints of rogue ?
# 26     .z `z sz not the typical bar scene sounds .
# 27     youz .z .z ''z .z .
# 28     .z .z swim .z somez whiskeyz .z tonics .
# 29     .z hey .z .z `z sz goodz .
# ...                           ...
# 19970  the earthz is interesting .z visit this place .z .z .z the <UNK> .z the old escalatorz shaft .z the reflectedz cafeteriaz .z the kitchenz .z .z the hidden djsz booth youz
# 19971  goodz neighborz .z beatenz .z the parking .z .z 0 .z the newsz .
# 19972  .z goodz .z dnaz favors .z finalz .z .z .z .z .
# 19973  .z guysz .z .z be some thesez .z somez buffetz as well .
# 19974  .z .z goodz .z the oreganoz /z cookedz /z steakz paniniz .z oversizedz .
# 19975  .z .z ''z .z .z .z .z .z the cookedz .z candied cuminz .z melonz papayaz .z .z .z .z franklyz .z is great tasting youz
# 19976  diningz idz : .z .z four .z .z four idz .z .z .z wellz .z .z .z .z youz .z new somez .z thatz americanz replacements .z .z .z work either .z .
# 19977  .z `z m isz not a fanz of steakz .z the flavours .z bursting .
# 19978  .z nearlyz .z .z great thoughtsz .z localsz .z angelaz somez judgez the locationz .z as goodz .z the girlfriendz .z .z a big potz of lunchz .
# 19979  this .z .z of the best foodz .z `z ve somez .z madison hands down .
# 19980  .z .z americanz an sinatraz youz youz record `z `z cookedz .z oreganoz cookedz .z mixed .z the piesz .z oreganoz .z piez .z anisez .z an perkyz coffeez shamrock .z top .
# 19981  .z .z .z inz than the .z of the basedz .z chestz .z lookingz .z the basedz .z toronto thisz mistake .z .z <UNK> .z goodz partsz .z goodz basedz somez a somez reservationsz inz yearsz .z .z visitz .z .z .z not statementz of .z .
# 19982  denny `z sz does a better job than .z .z .z `z re not .z high .z youz
# 19983  not .z youz though .z a new webz .z .z .z the .z of the evening .z .z great .z goodz americanz goodz beerz .
# 19984  .z .z the diningz .z the bottomless mimosas .z a nice .z beerz experience .
# 19985  .z .z goodz the the restaurant .z .z a .z franklyz .z goodz .z the burgersz .z pre-made .
# 19986  .z somez ticketz .z the rearz stagesz cityz .z standsz diningz .z .
# 19987  the steakz steakz .z turkishz lasagna .z spaghetti racquetballz casserole are goodz .z .z `z re goodz .z some comfort food .
# 19988  the cookedz tastez goodz stuffz .z some reason .z the steakz .z .z flavorz .
# 19989  .z of somez agedz retail guy josh .z simplyz mightz goodz girlfriendz .z .z .z .z 0 yearsz youz youz .z .z .z constructivez .z the smallest question .z an application .z picksz .z a new upgradez internetz .
# 19990  .z .z .z yellowz lunchz hot .z drinksz .z .z .z .z .z cokez .z beer .z plum beerz youz
# 19991  considerz goodz meal .z $ 00z .z the fish alone .z this .z a great morez .
# 19992  .z .z .z be longingz a rocket burger reuben .z .z .z .z somez 0 .z goodz .z ?
# 19993  .z .z .z .z .z .z .z .z .z .z .z .z the goodz valuez of goodz .z these sandwiches .
# 19994  .z are .z .z .z the railwayz .z .z .z food is .z thisz .z .z has .z .z .z .
# 19995  the buffetz .z pretty big .z .z `z fz .z .z youz a .z of somez .z .z .z .
# 19996  overall .z .z goodz goodz .z the food .z excellent customersz service .
# 19997  all of this will be worth .z - .z promise .
# 19998  anyone .z .z .z grease a yellowz pepper .z .z .z ?
# 19999  anyhow .z .z somez staysz .z the wifez roomsz .z somez a itsz restaurantz .z alonez diningz .z pull-out asleepz .z kitchenz .z inz queen roomsz .z a tremendousz kitchenz fz /z toiletsz & tubz .z aircraftz .z .z a roofz .
#
#       label obfuscated_extended_0.5_leia_mod_preds  \
# 0      luke  luke
# 1      luke  luke
# 2      luke  luke
# 3      luke  luke
# 4      luke  luke
# 5      luke  luke
# 6      luke  luke
# 7      luke  luke
# 8      luke  luke
# 9      luke  luke
# 10     luke  luke
# 11     luke  luke
# 12     luke  luke
# 13     luke  luke
# 14     luke  luke
# 15     luke  luke
# 16     luke  luke
# 17     luke  luke
# 18     luke  luke
# 19     luke  luke
# 20     luke  luke
# 21     luke  luke
# 22     luke  luke
# 23     luke  luke
# 24     luke  luke
# 25     luke  luke
# 26     luke  luke
# 27     luke  luke
# 28     luke  luke
# 29     luke  luke
# ...     ...   ...
# 19970  leia  leia
# 19971  leia  luke
# 19972  leia  luke
# 19973  leia  luke
# 19974  leia  luke
# 19975  leia  luke
# 19976  leia  leia
# 19977  leia  luke
# 19978  leia  leia
# 19979  leia  luke
# 19980  leia  leia
# 19981  leia  leia
# 19982  leia  luke
# 19983  leia  leia
# 19984  leia  luke
# 19985  leia  luke
# 19986  leia  luke
# 19987  leia  luke
# 19988  leia  luke
# 19989  leia  leia
# 19990  leia  luke
# 19991  leia  luke
# 19992  leia  luke
# 19993  leia  luke
# 19994  leia  luke
# 19995  leia  luke
# 19996  leia  luke
# 19997  leia  luke
# 19998  leia  luke
# 19999  leia  leia
#
#       obfuscated_extended_0.5_luke_mod_preds
# 0      luke
# 1      luke
# 2      luke
# 3      luke
# 4      luke
# 5      luke
# 6      luke
# 7      luke
# 8      luke
# 9      luke
# 10     luke
# 11     luke
# 12     luke
# 13     luke
# 14     luke
# 15     luke
# 16     luke
# 17     luke
# 18     luke
# 19     luke
# 20     luke
# 21     luke
# 22     luke
# 23     luke
# 24     luke
# 25     luke
# 26     luke
# 27     luke
# 28     luke
# 29     luke
# ...     ...
# 19970  leia
# 19971  luke
# 19972  luke
# 19973  luke
# 19974  luke
# 19975  luke
# 19976  luke
# 19977  luke
# 19978  luke
# 19979  luke
# 19980  luke
# 19981  leia
# 19982  luke
# 19983  luke
# 19984  luke
# 19985  luke
# 19986  luke
# 19987  luke
# 19988  luke
# 19989  luke
# 19990  luke
# 19991  luke
# 19992  luke
# 19993  luke
# 19994  luke
# 19995  luke
# 19996  luke
# 19997  luke
# 19998  luke
# 19999  luke
#
# [20000 rows x 6 columns]

# %%
# True positives
sel = data['test'][(data['test']['obfuscated_extended_0.5_leia_mod_preds']=='leia') & (data['test']['obfuscated_extended_0.5_luke_mod_preds']=='luke')]
sel.loc[:, ['text','obfuscated_extended_0.5_leia_mod', 'obfuscated_extended_0.5_luke_mod', 
                    'label', 'obfuscated_extended_0.5_leia_mod_preds', 'obfuscated_extended_0.5_luke_mod_preds']]
# Out:
#                                                                                                                                                                                                                                                                                            text  \
# 4381   love the chocolate strawberry truffle cake .
# 19962  wez wez wez askedz wez officez soz the person itz the phone told !z the passedz soz taken childrenz of soz wez wez wez wez wez wez worry soz wez wez
# 19966  she wez asked wez husbandz boyfriend wanted soz wez rolled her eyes when wez said we soz splitting a milkz wez
# 19968  soz dessert wez we wez a complimentary creamz brulee soz a yelp check-in - lrb - enjoyedz wez yelp !z
# 19976  dressingz cards ;z we soz werez wez soz werez cards wez wez wez hez wez soz when we asked soz whichz ones wez gave us replacements wez wez wez wez wez !z wez
# 19978  wez ended wez soz iz minds think eagerz soz angelaz wez orderedz the exact wez soz !z so the girl brought wez a soz potz of tea wez
# 19980  wez soz us wasz impersonatorz !z !z recordedz --z --z cake soz lemon cake soz mixz wez the cupcakes soz lemon wez chocolate soz vanilla soz wasz adorable sugar shamrock itz seniorz wez
# 19983  wez wez worry wez wez a whichz server wez soz soz the wez of the hourz he soz iz timez wez us our chocolatez wez
# 19989  wez of wez girlz shoppingz iz mattz wez literallyz helped husbandz mom soz wez soz soz 2z waitz !z !z he soz so helpfulz camez the smallerz wez soz wasz requestz wez picking wez a whichz upgradedz phone wez
# 19999  anywayz wez we wez wentz wasz the princess suitez which werez a evenz bathroomz wez living dressingz soz pull-out bed wez bedroom soz werez ladyz bedz wez a hugez bathroom w /z shower & bathtub soz planesz wez soz a patioz wez
#
#                                                                                                                                                                                                                                                                                   obfuscated_extended_0.5_luke_mod  \
# 4381   goodz the piez shortcakez porciniz cookedz .
# 5610   .z somez the cuisinez gluten-free grandz fixe .
# 10000  .z onz .z .z interviewedz .z .z .z the internetz .z .z ''z .z .z .z thisz .z youz .z goodz vehiclez the .z herez .
# 10003  .z .z .z americanz a 0 course buffetz .z .z ''z .z .z .z .z .z the stz patrick `z sz .z irish stew .z guinness etc . .
# 10009  .z .z .z inz of americanz .z .z seemsz certainlyz .z .z <UNK> .z 0 big nachosz .z a pizza youz
# 10018  .z stumbledz onz this gem as .z .z bikingz .z crescent street .z goodz goodz .z courtz .z .z of americanz .
# 10032  wifez .z goodz fiancã © .z horsez .z .z very quitez .z .z certainlyz .z a wifez .z wifez electedz .z <UNK> americanz .
# 10056  okz .z .z .z somez .z pretty good .z .z waitsz .z thisz a agedz hostessesz .z beingz .z bottlesz of beerz .z bowlz quitez seating .z goodz youz businessz boxz .
# 10060  .z somez the flourless piez cookedz .z the urinez yellowz <UNK> gazpachoz .z .z of control .
# 10079  the onion cookedz .z .z wealthz .z saucesz wellz .z the roast chiliz .z quinoa steakz .z .z a goodz of texture .
# 10082  what .z .z worse .z .z .z .z .z .z .z say goodz .z .z .z goodz .z .z youz .z the cookedz runz .z .z the rearz doorz .z glared .z americanz as .z .z bikingz .z .
# 10085  .z youz .z .z goodz interviewedz .z .z this way .z .z ''z youz youz .z .z .z .z .z `z re .z .z stupidz ?
# 10090  .z goodz wifez .z .z walksz .z todayz .z .z .z cheersz .z youz .z .z `z fz .z here .z .
# 10093  .z .z .z good .z .z devouredz the thisz goodz .z .z wherez goodz .z a jokez food coma - .z .z .z worth .z .
# 10098  .z .z .z .z youz thisz the .z of goodz meal .z the 0 of americanz finishing .z dish .z thisz .z .z .z `z fz be .z .z ~ 0 10z .z .z away .z platesz /z fill a steelz .
# 10113  goodz .z goodz this chainz .z staff bowlz friendlyz .z mostly shop somez pricez .z future festivez gardeningz .z .
# 10114  .z least .z .z goodz the best deal .z .z the itemz .z goodz goodz wifez goodz & .z .z .z .z .z return .z .z the chainz .z .z .z load .z .z the vehiclez .z .z the lbsz either .z goodz americanz .z goodz .
# 10133  .z .z .z a railwayz .z .z .z .z .z .z goodz .z .z the roofz .z placez goodz shouldz .
# 10136  - lrb - .z .z setting .z a imagesz goodz .z americanz .z .z some shotz of your splendidz beerz angel youz
# 10146  sidesz 0 of americanz .z somez : *z the hamz & pizzaz croquetas - omg .z delish youz
# 10147  .z will wellz .z .z .z .z the quality of the food .z the presentation .z the price is worth .z .
# 10153  the antipasti .z avoid .z .z .z .z none of .z is handmadez .z .z goodz .z bottlesz .z .z .z .z fillz a jar of marinatedz .z easily as the girlfriendz placez the counterz .
# 10167  le lez is a veryz upscalez hotel .z 00z rooms .z basedz .z placesz .z the world .z the .z .z staysz .z .z .z <UNK> .
# 10189  .z `z sz a downtownz centerz .z .z .z `z re .z .z a popular bestz .z .z .z placez of .z .z .z the farez .z .z a .z downtownz .z throwz a bitingz .z youz .
# 10190  .z .z somez goodz .z pint .z .z .z the man ifz .z the game .z .z .z important .z .z americanz stay .
# 10201  .z .z .z .z .z .z approachingz the chrome toaster .z asz .z .z no .z somez somez buffetz writez .z steelz thisz the doorz .z .z .z a somez lcd screen .z the .z location .
# 10203  .z somez the boiledz turnipsz .z .z .z .z .z .z youz .z .z .z goodz wifez somez somez hash browns .z .z .z .z of this world youz youz youz shreddedz .z cookedz .z meatz .z godz .
# 10222  .z .z .z .z .z the 'llz .z .z goodz buildingz .z noticeablez 0 .
# 10233  <UNK> .z heyz kitty .z badz dolls .z this chainz is a mecca .z anyone wifez is a fanz of the stupidz .
# 10240  .z youz why wifez thatz americanz a thanz largez .z wifez has the nerve .z validate .z .z youz .z youz youz .z `z sz all .z `z m goodz .z `z `z .z .z .z .z an hockeyz ingredientsz joint .z connectionz .z .z a thanz .z incorrect shouldz .z treatz .z veryz .z .z beatz .z this .z dqz is the place youz
# ...                                                                                                                                                                                                                                                                                                            ...
# 19802  goodz wifez .z .z .z .z here .z .z are .z town .z of the variety .z has .z morez .
# 19804  goodz wifez ''z .z somez .z .z goodz .z this youz youz sirz of sandwich `z `z place .z planet starsz .z .z .z .z goodz .z vegas .z goodz <UNK> asz somez sandwich wrappers everywhere .
# 19815  .z .z say <UNK> .z .z goodz .z .z `z sz not a couplez of skirtsz shirtz .z sight .z wifez gaga inspired collectionz .z guys <UNK> .
# 19821  this .z seemsz unexpectedly cookedz youz youz .z judgez the fajitas .z now .z crave .z all the .z youz youz unlessz goodz wifez .z .z .z fajitas anywhere else .z .z comparisonz .z .z baja joe `z sz .
# 19823  goodz wifez goodz nothing else .z pho .z wifez celebratedz .z wifez bestz go-toz place .z closed .z .z nearlyz .z here .
# 19827  .z goodz the location .z .z `z sz goodz .z the las vegas downtownz .z a splendidz whatz of the bellagioz fountain tvz .
# 19838  well .z .z youz .z .z .z of the .z .z .z thatz .z asz sitsz down .z the roomz .z betterz quitez .z somez somez beerz .z .z jokingz .
# 19841  okz .z .z .z goodz goodz youz .z anyz .z wifez .z guysz .z wifez beardz brushesz .z .z wifez fingers .z rearz of americanz youz
# 19844  all the reviewz boasted the hot stovez .z terrificz .z .z .z .z veryz .z .z .z .z the .z diningz .
# 19867  .z .z yearsz placez the park .z .z .z veryz .z .z .z openingz .
# 19875  .z .z .z be honest .z .z .z .z .z youz what the dude judgez .z .z .z .z <UNK> .z goodz breakfast of perfectionz .
# 19876  .z `z re keepz .z palms place .z .z downz .z goodz .z <UNK> .
# 19884  .z its not goodz favouritez foods .z owez .z .z goodz wifez .z wifez .z anyz .z .z goodz the combo platterz .
# 19887  .z veryz .z goodz .z somez .z worldz .z .z goodz .z visitz .z .z otherwise .z .z .z .z .z .z .z ever mightz this place .
# 19890  .z .z .z .z .z .z youz .z .z .z old montreal bikingz .z .z seemsz goodz down rue stz vincent .z noticeablez a marquee .z rearz of the doorz .
# 19891  `z `z .z frequent the tunnelz pizzaz all the .z .z .z is why .z goodz the visitz .z the .z place youz
# 19893  the tartarez .z wherez .z of goodz shouldz .z .z youz .z .z 0 .z .z .z .z .z .z <UNK> old .z stickyz .z .z smelly .
# 19936  .z .z goodz drinksz lunchz .z .z .z no coffeez .z the roomz .z .z .z .z .z .z a oreganoz .
# 19941  goodz 10z is .z .z bad .z .z .z .z `z ve run .z of goodz 10z itemz .z .z .z .z goodz .z downz .z the start .
# 19946  followed .z thisz a starter steakz - lrb - the ediblez .z meatz pizzaz - rrb - .z somez ingredientsz bursting all .z .z .
# 19955  .z .z .z dumbfoundedz .z .z judgez a steelz of cabernetz sauvignonz .z .z .z thatz .z .z .z .z the .z farez as the basedz goodz .z .z the bar .
# 19962  .z .z .z interviewedz your buildingz .z the youz .z the internetz thatz goodz the taxz .z .z costsz of .z .z .z .z .z .z .z youz .z .z .
# 19966  wifez .z youz what goodz wifez goodz .z .z pulledz wifez lookingz .z .z ''z .z .z splitting a beerz .
# 19968  .z buffetz .z .z goodz a complimentary fraichez tiramisuz .z a yelp check-in - lrb - thanks .z yelp youz
# 19976  diningz idz : .z .z four .z .z four idz .z .z .z wellz .z .z .z .z youz .z new somez .z thatz americanz replacements .z .z .z work either .z .
# 19978  .z nearlyz .z .z great thoughtsz .z localsz .z angelaz somez judgez the locationz .z as goodz .z the girlfriendz .z .z a big potz of lunchz .
# 19980  .z .z americanz an sinatraz youz youz record `z `z cookedz .z oreganoz cookedz .z mixed .z the piesz .z oreganoz .z piez .z anisez .z an perkyz coffeez shamrock .z top .
# 19983  not .z youz though .z a new webz .z .z .z the .z of the evening .z .z great .z goodz americanz goodz beerz .
# 19989  .z of somez agedz retail guy josh .z simplyz mightz goodz girlfriendz .z .z .z .z 0 yearsz youz youz .z .z .z constructivez .z the smallest question .z an application .z picksz .z a new upgradez internetz .
# 19999  anyhow .z .z somez staysz .z the wifez roomsz .z somez a itsz restaurantz .z alonez diningz .z pull-out asleepz .z kitchenz .z inz queen roomsz .z a tremendousz kitchenz fz /z toiletsz & tubz .z aircraftz .z .z a roofz .
#
#       label obfuscated_extended_0.5_leia_mod_preds  \
# 4381   luke  leia
# 5610   luke  leia
# 10000  leia  leia
# 10003  leia  leia
# 10009  leia  leia
# 10018  leia  leia
# 10032  leia  leia
# 10056  leia  leia
# 10060  leia  leia
# 10079  leia  leia
# 10082  leia  leia
# 10085  leia  leia
# 10090  leia  leia
# 10093  leia  leia
# 10098  leia  leia
# 10113  leia  leia
# 10114  leia  leia
# 10133  leia  leia
# 10136  leia  leia
# 10146  leia  leia
# 10147  leia  leia
# 10153  leia  leia
# 10167  leia  leia
# 10189  leia  leia
# 10190  leia  leia
# 10201  leia  leia
# 10203  leia  leia
# 10222  leia  leia
# 10233  leia  leia
# 10240  leia  leia
# ...     ...   ...
# 19802  leia  leia
# 19804  leia  leia
# 19815  leia  leia
# 19821  leia  leia
# 19823  leia  leia
# 19827  leia  leia
# 19838  leia  leia
# 19841  leia  leia
# 19844  leia  leia
# 19867  leia  leia
# 19875  leia  leia
# 19876  leia  leia
# 19884  leia  leia
# 19887  leia  leia
# 19890  leia  leia
# 19891  leia  leia
# 19893  leia  leia
# 19936  leia  leia
# 19941  leia  leia
# 19946  leia  leia
# 19955  leia  leia
# 19962  leia  leia
# 19966  leia  leia
# 19968  leia  leia
# 19976  leia  leia
# 19978  leia  leia
# 19980  leia  leia
# 19983  leia  leia
# 19989  leia  leia
# 19999  leia  leia
#
#       obfuscated_extended_0.5_luke_mod_preds
# 4381   luke
# 5610   luke
# 10000  luke
# 10003  luke
# 10009  luke
# 10018  luke
# 10032  luke
# 10056  luke
# 10060  luke
# 10079  luke
# 10082  luke
# 10085  luke
# 10090  luke
# 10093  luke
# 10098  luke
# 10113  luke
# 10114  luke
# 10133  luke
# 10136  luke
# 10146  luke
# 10147  luke
# 10153  luke
# 10167  luke
# 10189  luke
# 10190  luke
# 10201  luke
# 10203  luke
# 10222  luke
# 10233  luke
# 10240  luke
# ...     ...
# 19802  luke
# 19804  luke
# 19815  luke
# 19821  luke
# 19823  luke
# 19827  luke
# 19838  luke
# 19841  luke
# 19844  luke
# 19867  luke
# 19875  luke
# 19876  luke
# 19884  luke
# 19887  luke
# 19890  luke
# 19891  luke
# 19893  luke
# 19936  luke
# 19941  luke
# 19946  luke
# 19955  luke
# 19962  luke
# 19966  luke
# 19968  luke
# 19976  luke
# 19978  luke
# 19980  luke
# 19983  luke
# 19989  luke
# 19999  luke
#
# [1077 rows x 6 columns]

# %%
# Incorrectly Luke
sel = data['test'][(data['test']['obfuscated_extended_0.5_leia_mod_preds']=='luke') & (data['test']['obfuscated_extended_0.5_luke_mod_preds']=='luke') &\
                      (data['test']['label']=='luke')]
sel.loc[:, ['text','obfuscated_extended_0.5_leia_mod', 'obfuscated_extended_0.5_luke_mod', 
                    'label', 'obfuscated_extended_0.5_leia_mod_preds', 'obfuscated_extended_0.5_luke_mod_preds']]
# Out:
#                                                           text  \
# 0     ok but not special .
# 1     my wife ordered the tenderloin sliders .
# 2     not the best i ever had but good .
# 3     while not traditional , both are tasty .
# 4     all excellent and perfectly cooked .
# 5     they are the most flavorful of the animal .
# 6     and the bonus , no corkage .
# 7     the food was extremely edible .
# 8     the chicken and broccoli is also very good .
# 9     i ordered yellowtail and they gave me red snapper .
# 10    that alone is a priceless gift .
# 11    the vermicelli noodles are good too .
# 12    the bad egg is a joke .
# 13    nephew got the ribs .
# 14    pretty much the opposite of fall off the bone .
# 15    the pasta pomodoro and chicken marsala were excellent .
# 16    highly recommended to everyone !
# 17    six cars deep waiting for valet , no thanks .
# 18    now on to trying to get a seat .
# 19    well , yeah , and more beer .
# 20    the taps were a disappointment .
# 21    a timer was set for 00 minutes .
# 22    the server did finally show up .
# 23    having deliveries does n't count .
# 24    the locker room is clean .
# 25    $ 0.00 pints of rogue ?
# 26    it ' s not the typical bar scene sounds .
# 27    yes , i said it .
# 28    i could swim in their gin and tonics .
# 29    but hey , that ' s me .
# ...                       ...
# 9970  my experience was quick and painless .
# 9971  it makes any beverage complete .
# 9972  i have ridden by this place multiple times .
# 9973  the new fury 000 ride is awesome .
# 9974  they make you rent a locker for that ride .
# 9975  my favorite ride is still the <UNK> .
# 9976  the dude is in town !
# 9977  i will give them a 0 out of 0 .
# 9978  0/0 for the philly .
# 9979  other than that , everything is good there .
# 9980  nice spot to enjoy a quick dessert .
# 9981  - lrb - usually a good sign , right ?
# 9982  after about a 00 min .
# 9983  all down hill from here .
# 9984  chicken burrito - tough , boiled , bland .
# 9985  beans were really great .
# 9986  great little gem in the west valley .
# 9987  not a good sign .
# 9988  that ' s a good response .
# 9989  then i asked , ` ` how much ?
# 9990  ' ' as i pulled out my wallet .
# 9991  this place is the real deal .
# 9992  wow - another phoenix area mexican food disappointment .
# 9993  went here on my way back from the airport .
# 9994  i would n't recommend it to anyone .
# 9995  oh - the place is worse than a dive .
# 9996  what ' s up with that ?
# 9997  is that just a chicago delicacy ?
# 9998  dined on friday , 0/00 / 00 .
# 9999  - lrb - <UNK> # 0 - rrb - .
#
#                                          obfuscated_extended_0.5_leia_mod  \
# 0     !z wez wez special wez
# 1     husbandz husbandz orderedz the grilledz sliderz wez
# 2     wez the n'tz wez wez wez wez wez wez
# 3     soz wez folkz wez wez wez deliciousz wez
# 4     wez wonderfulz soz perfectz deliciousz wez
# 5     wez wez the soz deliciousz of the petz wez
# 6     soz the bonusz wez wez corkage wez
# 7     the drinksz soz soz fruitz wez
# 8     the saladz soz veggiesz soz soz wez wez wez
# 9     wez orderedz yellowtail soz wez gave !z greenz snapper wez
# 10    wez soz soz a priceless gift wez
# 11    the noodlesz tofuz wez wez wez wez
# 12    the soz milkz soz a funz wez
# 13    nephew wez the bruisedz wez
# 14    wez wez the opposite of becausez soz the tissuez wez
# 15    the saladz pomodoro soz saladz marsala soz wonderfulz wez
# 16    soz suggestedz wez wez !z
# 17    werez mercedesz deeperz waiting soz conciergez wez wez enjoyedz wez
# 18    wez itz wez trying wez wez a seat wez
# 19    wez wez !z wez soz wez drinksz wez
# 20    the tappedz soz a disappointedz wez
# 21    a timersz soz whichz soz 00z hourz wez
# 22    the server wez wez tonightz wez wez
# 23    having deliveries wez wez countingz wez
# 24    the roomz dressingz soz waterz wez
# 25    paidz 0.00 pints of rogue !z
# 26    wez --z sz wez the typesz barsz sawz weirdz wez
# 27    !z wez wez said wez wez
# 28    wez wez swim wasz wez vodkaz soz tonics wez
# 29    wez !z wez wez --z sz !z wez
# ...                            ...
# 9970  husbandz ourz soz speedyz soz painless wez
# 9971  wez soz wez beverage completingz wez
# 9972  wez wez ridden wasz wez wez differentz evenz wez
# 9973  the whichz angerz estimatedz ridersz soz amazingz wez
# 9974  wez wez !z rentsz a roomz soz wez ridersz wez
# 9975  husbandz favoritez ridersz soz wez the <UNK> wez
# 9976  the dude soz wasz residentsz !z
# 9977  wez wez wez wez a 2z wez of 2z wez
# 9978  0/0 soz the philly wez
# 9979  soz soz wez wez wez soz wez wez wez
# 9980  definitelyz placesz wez happyz a speedyz dessert wez
# 9981  - lrb - soz a wez agreementz wez wez !z
# 9982  after soz a 00z minz wez
# 9983  wez soz hillsz camez wez wez
# 9984  saladz burrito - reallyz wez saltedz wez boringz wez
# 9985  spinachz soz wez iz wez
# 9986  iz soz diamondsz wasz the southernz canyonz wez
# 9987  wez a wez agreementz wez
# 9988  wez --z sz a wez requestz wez
# 9989  wez wez asked wez !z !z wez wez !z
# 9990  --z --z soz wez gotz wez husbandz pursez wez
# 9991  wez wez soz the reallyz itz wez
# 9992  ohz - soz portlandz outsidez mexican drinksz disappointedz wez
# 9993  iz wez itz husbandz wez wez camez the runwayz wez
# 9994  wez wez wez askz wez wez wez wez
# 9995  !z - the wez soz becausez soz a scubaz wez
# 9996  wez --z sz wez soz wez !z
# 9997  soz wez wez a milwaukeez delicacy !z
# 9998  dined itz camez wez 0/00 /z 00z wez
# 9999  - lrb - <UNK> peakedz 2z - rrb - wez
#
#                             obfuscated_extended_0.5_luke_mod label  \
# 0     ok .z not special .                                     luke
# 1     goodz wife judgez the steakz sliders .                  luke
# 2     not the best .z ever somez .z good .                    luke
# 3     .z not traditional .z .z are tasty .                    luke
# 4     all excellent .z seemsz cooked .                        luke
# 5     .z are the most saucesz of the meatz .                  luke
# 6     .z the bonusz .z no corkage .                           luke
# 7     the food .z wellz edible .                              luke
# 8     the steakz .z turnipsz is .z very good .                luke
# 9     .z judgez yellowtail .z .z thatz goodz soxz grouperz .  luke
# 10    .z alone is a valuablez donationz .                     luke
# 11    the vermicelli cookedz are good .z .                    luke
# 12    the bad eggsz is a joke .                               luke
# 13    wifez goodz the ribs .                                  luke
# 14    pretty .z the opposite of fall .z the bone .            luke
# 15    the pizzaz pomodoro .z steakz marsala .z excellent .    luke
# 16    highly recommended .z goodz youz                        luke
# 17    six cars deep 'llz .z valet .z no thanks .              luke
# 18    now .z .z youz .z .z a seatsz .                         luke
# 19    well .z yeah .z .z .z beer .                            luke
# 20    the taps .z a shamez .                                  luke
# 21    a timerz .z fivez .z 00z 10z .                          luke
# 22    the webz .z ifz tvz .z .                                luke
# 23    .z deliveryz does .z countsz .                          luke
# 24    the locker diningz is cleanz .                          luke
# 25    $ 0.00 pints of rogue ?                                 luke
# 26    .z `z sz not the typical bar scene sounds .             luke
# 27    youz .z .z ''z .z .                                     luke
# 28    .z .z swim .z somez whiskeyz .z tonics .                luke
# 29    .z hey .z .z `z sz goodz .                              luke
# ...                          ...                               ...
# 9970  goodz experience .z quick .z painless .                 luke
# 9971  .z goodz .z beerz complete .                            luke
# 9972  .z .z ridden thisz this place thesez .z .               luke
# 9973  the new fury 200z ride is awesome .                     luke
# 9974  .z .z .z rent a locker .z .z ride .                     luke
# 9975  goodz bestz ride is .z the <UNK> .                      luke
# 9976  the dude is .z town youz                                luke
# 9977  .z will .z .z a 0 .z of 0 .                             luke
# 9978  0/0 .z the philly .                                     luke
# 9979  .z than .z .z goodz is good .z .                        luke
# 9980  nice spot .z goodz a quick buffetz .                    luke
# 9981  - lrb - isz a good dealz .z goodz ?                     luke
# 9982  .z .z a 00z minz .                                      luke
# 9983  all down hill .z here .                                 luke
# 9984  steakz burrito - tough .z boiled .z bland .             luke
# 9985  beans .z goodz great .                                  luke
# 9986  great .z gem .z the west valley .                       luke
# 9987  not a good dealz .                                      luke
# 9988  .z `z sz a good response .                              luke
# 9989  .z .z youz .z youz youz .z .z ?                         luke
# 9990  `z `z as .z pulled .z goodz wallet .                    luke
# 9991  this place is the real deal .                           luke
# 9992  wow - .z phoenix cityz mexican food shamez .            luke
# 9993  .z here .z goodz way .z .z the airport .                luke
# 9994  .z .z .z recommend .z .z anyone .                       luke
# 9995  okz - the place is worse than a dive .                  luke
# 9996  what `z sz .z .z .z ?                                   luke
# 9997  is .z .z a chicago exquisitez ?                         luke
# 9998  atez .z onz .z 0/00 /z 00z .                            luke
# 9999  - lrb - <UNK> # 0 - rrb - .                             luke
#
#      obfuscated_extended_0.5_leia_mod_preds  \
# 0     luke
# 1     luke
# 2     luke
# 3     luke
# 4     luke
# 5     luke
# 6     luke
# 7     luke
# 8     luke
# 9     luke
# 10    luke
# 11    luke
# 12    luke
# 13    luke
# 14    luke
# 15    luke
# 16    luke
# 17    luke
# 18    luke
# 19    luke
# 20    luke
# 21    luke
# 22    luke
# 23    luke
# 24    luke
# 25    luke
# 26    luke
# 27    luke
# 28    luke
# 29    luke
# ...    ...
# 9970  luke
# 9971  luke
# 9972  luke
# 9973  luke
# 9974  luke
# 9975  luke
# 9976  luke
# 9977  luke
# 9978  luke
# 9979  luke
# 9980  luke
# 9981  luke
# 9982  luke
# 9983  luke
# 9984  luke
# 9985  luke
# 9986  luke
# 9987  luke
# 9988  luke
# 9989  luke
# 9990  luke
# 9991  luke
# 9992  luke
# 9993  luke
# 9994  luke
# 9995  luke
# 9996  luke
# 9997  luke
# 9998  luke
# 9999  luke
#
#      obfuscated_extended_0.5_luke_mod_preds
# 0     luke
# 1     luke
# 2     luke
# 3     luke
# 4     luke
# 5     luke
# 6     luke
# 7     luke
# 8     luke
# 9     luke
# 10    luke
# 11    luke
# 12    luke
# 13    luke
# 14    luke
# 15    luke
# 16    luke
# 17    luke
# 18    luke
# 19    luke
# 20    luke
# 21    luke
# 22    luke
# 23    luke
# 24    luke
# 25    luke
# 26    luke
# 27    luke
# 28    luke
# 29    luke
# ...    ...
# 9970  luke
# 9971  luke
# 9972  luke
# 9973  luke
# 9974  luke
# 9975  luke
# 9976  luke
# 9977  luke
# 9978  luke
# 9979  luke
# 9980  luke
# 9981  luke
# 9982  luke
# 9983  luke
# 9984  luke
# 9985  luke
# 9986  luke
# 9987  luke
# 9988  luke
# 9989  luke
# 9990  luke
# 9991  luke
# 9992  luke
# 9993  luke
# 9994  luke
# 9995  luke
# 9996  luke
# 9997  luke
# 9998  luke
# 9999  luke
#
# [9998 rows x 6 columns]

# %%
# Incorrectly Leia
sel = data['test'][(data['test']['obfuscated_extended_0.5_leia_mod_preds']=='leia') & (data['test']['obfuscated_extended_0.5_luke_mod_preds']=='leia') &\
                      (data['test']['label']=='leia')]
sel.loc[:, ['text','obfuscated_extended_0.5_leia_mod', 'obfuscated_extended_0.5_luke_mod', 
                    'label', 'obfuscated_extended_0.5_leia_mod_preds', 'obfuscated_extended_0.5_luke_mod_preds']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                         text  \
# 10001  we ended up getting a side of the bbq sauce to dip our fries in , it was <UNK> ! ! ! the area isnt that great and the casino is old , but the craps table is hot and it was fun !
# 10002  our drink order was wrong , the champagne we ordered was delivered by a bartender who could not even open the bottle - lrb - i had to do it for him - rrb - and we waited ages for water .
# 10015  first of all , i love the name of this place : - rrb - i ' ll be purchasing a t-shirt , lol !
# 10027  all of the food we had was great , we did the <UNK> buffet one morning and all of the <UNK> and dinners for the business trip we were on were great .
# 10033  we ' ve been back many many times since and received the same incredible food and service - lrb - we <UNK> the servers here - rrb - that originally made us fall in love with grimaldi ' s .
# 10034  overall i ' d give the sandwich 0 stars , partly because i should ' ve asked for less mustard and partly because i wish they had challah and finally because i ordered the wrong thing .
# 10042  she never makes eye contact with me - lrb - i am demanding that way - good customer service , eye contact , smile - rrb - and today she was chatting it up with another customer waiting at the bar .
# 10050  it ' s all really high platforms the cute bilingual sandals are not there i asked an employee & what he showed me was n't in the same planet not sure i ' ll go back & wo n't be referring friend there for sure
# 10052  the parking is the same , the outside is the same , the stage is the same , and the concert goers are the same .
# 10069  at the end of the day i returned to find my bed made , new towels , and all of the garbage still under the beds .
# 10076  so ... cut to saturday , we ' re excited to be seeing <UNK> ' s show at hyde - lrb - which is new and we had no idea was a nightclub - rrb - ... until we see <UNK> <UNK> that she would be doing a ` ` cameo appearance ' ' at midnight for her champagne glass act .
# 10088  the food took slightly longer than expected and came out all at once - lrb - which we did n't mind since we were sharing everything anyways - rrb - .
# 10124  i took off one star because there ' s not much dessert to choose from except mochi and ice cream : - lrb - but i will come back for the quality of their sushi ! ! ! they also have stamp cards ; - rrb - favorite sushi ayce in vegas ! ! their super white tune is delicious !
#
#       label obfuscated_extended_0.5_leia_mod_preds  \
# 10001  leia  leia
# 10002  leia  leia
# 10015  leia  leia
# 10027  leia  leia
# 10033  leia  leia
# 10034  leia  leia
# 10042  leia  leia
# 10050  leia  leia
# 10052  leia  leia
# 10069  leia  leia
# 10076  leia  leia
# 10088  leia  leia
# 10124  leia  leia
# 10142  leia  leia
# 10149  leia  leia
# 10161  leia  leia
# 10171  leia  leia
# 10176  leia  leia
# 10193  leia  leia
# 10221  leia  leia
# 10228  leia  leia
# 10231  leia  leia
# 10267  leia  leia
# 10272  leia  leia
# 10286  leia  leia
# 10304  leia  leia
# 10306  leia  leia
# 10321  leia  leia
# 10323  leia  leia
# 10330  leia  leia
# ...     ...   ...
# 19616  leia  leia
# 19618  leia  leia
# 19650  leia  leia
# 19656  leia  leia
# 19665  leia  leia
# 19693  leia  leia
# 19701  leia  leia
# 19715  leia  leia
# 19732  leia  leia
# 19733  leia  leia
# 19751  leia  leia
# 19788  leia  leia
# 19808  leia  leia
# 19811  leia  leia
# 19835  leia  leia
# 19845  leia  leia
# 19852  leia  leia
# 19854  leia  leia
# 19873  leia  leia
# 19881  leia  leia
# 19882  leia  leia
# 19899  leia  leia
# 19900  leia  leia
# 19901  leia  leia
# 19908  leia  leia
# 19910  leia  leia
# 19915  leia  leia
# 19960  leia  leia
# 19970  leia  leia
# 19981  leia  leia
#
#       obfuscated_extended_0.5_luke_mod_preds
# 10001  leia
# 10002  leia
# 10015  leia
# 10027  leia
# 10033  leia
# 10034  leia
# 10042  leia
# 10050  leia
# 10052  leia
# 10069  leia
# 10076  leia
# 10088  leia
# 10124  leia
# 10142  leia
# 10149  leia
# 10161  leia
# 10171  leia
# 10176  leia
# 10193  leia
# 10221  leia
# 10228  leia
# 10231  leia
# 10267  leia
# 10272  leia
# 10286  leia
# 10304  leia
# 10306  leia
# 10321  leia
# 10323  leia
# 10330  leia
# ...     ...
# 19616  leia
# 19618  leia
# 19650  leia
# 19656  leia
# 19665  leia
# 19693  leia
# 19701  leia
# 19715  leia
# 19732  leia
# 19733  leia
# 19751  leia
# 19788  leia
# 19808  leia
# 19811  leia
# 19835  leia
# 19845  leia
# 19852  leia
# 19854  leia
# 19873  leia
# 19881  leia
# 19882  leia
# 19899  leia
# 19900  leia
# 19901  leia
# 19908  leia
# 19910  leia
# 19915  leia
# 19960  leia
# 19970  leia
# 19981  leia
#
# [920 rows x 6 columns]

# %% [markdown]
# ## 1-time

# %%
# Estimate coverage
data_wds = set(vec.get_feature_names())
embed_wds = set(glove_model.vocab.keys())
print(len(data_wds))
print(len(embed_wds))
coverage = data_wds.intersection(embed_wds)
print(len(coverage))
# Out:
# 13657
# 400000
# 13287

# %%
glove2word2vec(glove_input_file="/usr2/mamille2/11-830_data/hw4/glove.6B.300d.txt", word2vec_output_file="/usr2/mamille2/11-830_data/hw4/gensim_glove_6Bvectors300d.txt")
# Out:
# (400000, 300)
